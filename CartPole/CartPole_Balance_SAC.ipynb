# %% [markdown]
# # Stabilize Inverted Cartpole with Deep Reinforcement Learning

# %% [markdown]
# In this notebook the environment of a inverted cartpole is implemented.
# The pendulum starts in a state very close to the unstable equilibrium $\theta \approx 0$.
# The goal is to create a reinforcement learning agent which will stabilize the cartpole in this inverted position. The trained neural network of the agent will observe the state $s_t$ of the physical system and will output the horizontal Force $f_t$ acting on the cart to control the cartpole system.
# No classical control theory will be used to achieve this.

# %% [markdown]
# ![rl.png](attachment:rl.png)

# %% [markdown]
# ## 1. Cartpole Environment

# %% [markdown]
# ![cart-pole-model.svg](attachment:cart-pole-model.svg)

# %% [markdown]
# Quelle: Colin D. Green - Equations of Motion for the Cart and Pole Control Task
#
# https://sharpneat.sourceforge.io/research/cart-pole/cart-pole-equations.html

# %% [markdown]
# $\ddot{x} = \frac{1}{(ml\cos(\varphi))^2 - M(J+ml^2)} \big[(ml)^2g\sin(\varphi)\cos(\varphi) - (J+ml^2)(f + ml\dot{\varphi}^2\sin(\varphi))\big]$
#
# $\ddot{\varphi} = \frac{1}{(ml\cos(\varphi))^2 - M(J+ml^2)} \big[  (ml\cos(\varphi)) (f+ml\dot{\varphi}^2\sin(\varphi)) - Mmgl\sin(\varphi)  \big]$

# %%
import numpy as np
from math import sin, cos
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
class CartPoleBalance:
    def __init__(self, max_force, max_phi, max_timesteps):
        self.state = None
        self.max_speed = 8.0 # [m/s], [rad/s]
        self.max_x = 3.0
        self.max_phi = max_phi
        self.max_force = max_force # [N]
        self.max_timesteps = max_timesteps
        
        self.m = 1.0  # mass of pole
        m_c = 1.0  # mass of cart
        self.M = self.m + m_c  # mass of system - both cart and pole
        self.g = 9.81
        self.l = 1.0
        self.J = (self.m*self.l*self.l)/3
        
        self.action_space_low = np.array([-self.max_force])
        self.action_space_high = np.array([self.max_force])
        
        self.observation_space_high = np.array([self.max_x, self.max_phi, self.max_speed, self.max_speed])
        self.observation_space_low = - np.array([self.max_x, self.max_phi, self.max_speed, self.max_speed])
        
        self.dt = 0.02
        self.steps = 0
        self.viewer = None
    
    def step(self, action):
        self.steps += 1
        x, phi, dx, dphi = self.state
        
        # force is bounded due to maximum motor torque of actuator
        F = np.clip(action, -self.max_force, self.max_force)[0]
        
        x0 = [x, phi, dx, dphi]
        integration_timesteps = np.linspace(0, self.dt, 4)
        X = odeint(self.cartpole_dXdt, x0, integration_timesteps, args=(F,))
        
        # pick last elements of trajectory
        x = X[-1, 0]  
        phi = X[-1, 1]
        dx = X[-1, 2]
        dphi = X[-1, 3]
        
        self.state = np.array([x, phi, dx, dphi])
        
        # epsidoe ends when done = True
        done = bool(
            x < -self.max_x
            or x > self.max_x
            or phi < -self.max_phi
            or phi > self.max_phi
            or self.steps >= self.max_timesteps)
        
        # reward function of transition s_t, action --> s_t+1
        #reward = 1.0 if not done else 0.0 # funktioniert
        #reward = 1.0 - 0.5*dx**2 if not done else -10.0 # funktioniert gut
        reward = 1.0 - 1.0*dx**2 - 1.2*x**2 - 10.0*phi**2 if not done else -20
        if self.steps >= self.max_timesteps:
            reward = reward + 80
            
        # Swing up: https://ww2.mathworks.cn/help/reinforcement-learning/ug/train-ddpg-agent-to-swing-up-and-balance-cart-pole-system.html
        
        return self.state, reward, done
        
    
    def cartpole_dXdt(self, X, t, F):  
        g = self.g
        m = self.m
        M = self.M
        l = self.l
        J = self.J

        x, phi, dx, dphi = X

        nenner = (m*l*cos(phi))**2 - M*(J + m*l*l)
        ddx = (m*m*l*l*g*sin(phi)*cos(phi) - (J+m*l*l)*(F + m*l*dphi*dphi*sin(phi))) / nenner
        ddphi = ( (m*l*cos(phi))*(F + m*l*dphi*dphi*sin(phi)) - m*M*g*l*sin(phi) ) / nenner

        return dx, dphi, ddx, ddphi
    
    def reset(self):
        self.steps = 0
        high = np.array([0.1, np.deg2rad(8), 0.001, 0.001]) # x, phi, dx, dphi
        self.state = np.random.uniform(low=-high, high=high)
        return self.state
    
    def render(self, mode='human'):
        '''render method from Gym Environment'''
        screen_width = int(1.5*600)
        screen_height = int(1.5*400)

        world_width = self.max_x * 2
        scale = 1.6*screen_width/world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (self.l)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            from gym.envs.classic_control import rendering
            self.viewer = rendering.Viewer(screen_width, screen_height)
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
            pole = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(.3, .9, .3) #(.8, .6, .4)
            self.poletrans = rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            self.axle = rendering.make_circle(polewidth/2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(.5, .5, .8)
            self.viewer.add_geom(self.axle)
            self.track = rendering.Line((0, carty), (screen_width, carty))
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
        pole.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state  # x, phi, dx, dphi
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, carty)
        self.poletrans.set_rotation(-x[1])

        return self.viewer.render(return_rgb_array=mode == 'rgb_array')

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %% [markdown]
# ## 2. Deep Reinforcement Learning Agent - Soft Actor-Critic (SAC)
#
# Implementation of newest style of SAC with two Q Networks and temperature parameter alpha optimization/tuning.

# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow_probability as tfp  # Distributions with reparam trick to gradients flow through
from tensorflow.keras.layers import Dense
from tensorflow.keras import initializers  # for layer weight initializing
import tensorflow.keras.losses as losses
import gym
import pybullet_envs
import matplotlib.pyplot as plt

# %%
class ReplayBuffer:
    def __init__(self, n_actions, input_shape, max_size=1000000):
        self.mem_size = max_size

        self.state_memory = np.zeros((self.mem_size, input_shape))
        self.new_state_memory = np.zeros((self.mem_size, input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

        self.n_count = 0

    def store_transition(self, state, action, reward, state_, done):
        index = self.n_count % self.mem_size

        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done

        self.n_count += 1

    def sample_buffer(self, batch_size=256):
        max_mem = min(self.n_count, self.mem_size)
        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

# %%
class CriticNetwork(tf.keras.Model):
    def __init__(self, n_states, n_actions, fc1_dims, fc2_dims, network_name, chkpt_dir='tmp/SAC', init_w=3e-3):
        super(CriticNetwork, self).__init__()

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')

        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states + n_actions, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        self.q = Dense(units=1,
                       kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w), # Änderung
                       bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))

    def call(self, state, action):
        inputs = tf.concat([state, action], axis=1)
        x = self.fc1(inputs)
        x = self.fc2(x)
        return self.q(x) 


class ActorNetwork(tf.keras.Model):
    def __init__(self,
                 n_states,
                 n_actions,
                 fc1_dims,
                 fc2_dims,
                 network_name,
                 chkpt_dir='tmp/SAC',
                 init_w=3e-3,
                 log_std_min=-20,
                 log_std_max=2):
        super(ActorNetwork, self).__init__()
        
        self.log_std_min = log_std_min
        self.log_std_max = log_std_max

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')
        
        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        
        self.mu = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        
        self.log_std = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        

    def call(self, state):
        x = self.fc1(state)
        x = self.fc2(x)
        mu = self.mu(x)
        
        log_std = self.log_std(x)
        log_std = tf.clip_by_value(log_std, clip_value_min=self.log_std_min, clip_value_max=self.log_std_max)
        std = tf.exp(log_std)
        
        normal = tfp.distributions.Normal(mu, std)  # make Gaussian distribution of mu, and sigma for actions
        
        z = normal.sample()  # sample from distribution with reparam trick
        action = tf.tanh(z)  # bound actions to [-1, +1]
        
        # correct log_probs because of bounding the actions
        log_prob = normal.log_prob(z) - tf.math.log(1 - tf.math.square(action) + 1e-6)  # Ist dasselbe!
        log_prob = tf.reduce_sum(log_prob, axis=1, keepdims=True) # tf.reduce_sum() or tf.reduce_mean()

        return action, log_prob

# %%
class Agent:
    """ 2019 State-of-the-Art Implementation of SAC with optimized temperature

    """
    def __init__(self,
                 env,
                 lr_Q = 3e-4,
                 lr_actor = 3e-4,
                 lr_a = 3e-4,
                 gamma=0.99,
                 tau=0.005,
                 layer1_size=256,
                 layer2_size=256,
                 batch_size=256,
                 max_size=1000000,
                 warmup=1000,
                 policy_delay=1,
                 minimum_entropy=None):

        self.env = env
        self.action_range = [env.action_space_low, env.action_space_high]

        self.n_states = env.observation_space_low.shape[0]
        self.n_actions = env.action_space_low.shape[0]

        self.min_action = env.action_space_low
        self.max_action = env.action_space_high

        self.gamma = gamma
        self.tau = tau
        self.batch_size = batch_size
        self.warmup = warmup
        self.time_step = 0
        self.update_step = 0
        self.policy_delay = policy_delay

        self.policy_net = ActorNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                       fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Actor')

        self.q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_1')

        self.q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_2')

        self.target_q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_1')

        self.target_q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_2')

        self.replay_buffer = ReplayBuffer(n_actions=self.n_actions,
                                          input_shape=self.n_states,
                                          max_size=max_size)
        
        self.policy_net.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_actor))
        self.q_net1.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))
        self.q_net2.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))

        self.update_target_network_parameters(tau=1)  # copy parameters to target networks

        # entropy temperature parameter alpha
        #self.log_alpha = tf.Variable(0.0, dtype=tf.float32)
        print(-tf.constant(env.action_space_low.shape[0], dtype=tf.float32))
        
        self.log_alpha = tf.Variable(tf.zeros(1), trainable=True)
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32))
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32)) if minimum_entropy is None else minimum_entropy
        print('Minimum Entropy set to: ', self.minimum_entropy)
        self.alpha_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_a)
        self.alpha = tf.exp(self.log_alpha).numpy()
        print('alpha: ', self.alpha)
        

    def choose_action(self, state):
        if self.time_step < self.warmup:
            actions = np.random.uniform(low=-1.0, high=1.0, size=self.n_actions)  # "random uniform distribution over all valid actions"
            actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        else:
            state = tf.convert_to_tensor(state, dtype=tf.float32)
            state = tf.expand_dims(state, axis=0)
            actions, _ = self.policy_net(state)

        self.time_step += 1
        if self.time_step == self.warmup:
            print('No warmup anymore!')
        a = self.rescale_action(actions[0].numpy())
        return a

    def scale_action(self, action):
        """ Scale all actions to [-1., +1.]

        :param action: unscaled actions
        :return: scaled actions all in range -1. .. +1.
        """
        #old = 2 * (action - self.min_action) / (self.max_action - self.min_action) - 1.0
        scale = (2 * action - (self.action_range[1] + self.action_range[0])) / (self.action_range[1] - self.action_range[0])
        return scale

    def rescale_action(self, action):
        """ Rescale all scaled actions to environment actionspace values

        :param action: scaled actions
        :return: rescaled actions all in range min_action .. max_action
        """
        #old = (action + 1.0) * (self.max_action - self.min_action) / 2.0 + self.min_action
        rescale = action * (self.action_range[1] - self.action_range[0]) / 2.0 + \
               (self.action_range[1] + self.action_range[0]) / 2.0
        return rescale

    def remember(self, state, action, reward, new_state, done):
        action = self.scale_action(action)  # ÄNDERUNG! Funktioniert das mit?
        self.replay_buffer.store_transition(state, action, reward, new_state, done)

    def update_target_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau
        
        weights = []
        for theta_target, theta in zip(self.target_q_net1.get_weights(), 
                                       self.q_net1.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net1.set_weights(weights)
        
        weights = []
        for theta_target, theta in zip(self.target_q_net2.get_weights(),
                                       self.q_net2.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net2.set_weights(weights)
        
        #weights = []
        #theta_target = self.target_q_net1.weights
        #for i, theta in enumerate(self.q_net1.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net1.set_weights(weights)
        # 
        #weights = []
        #theta_target = self.target_q_net2.weights
        #for i, theta in enumerate(self.q_net2.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net2.set_weights(weights)
        

    def save_models(self):
        print('...save models...') # To Do!

    def load_models(self):
        print('...load models...') # To Do!

    def learn(self):
        if self.replay_buffer.n_count < self.batch_size:
            return
        elif self.replay_buffer.n_count == self.batch_size:
            print('Buffer Size equals batch Size! - Learning begins :)')
            return
        
        # sample batch from replay buffer
        states, actions, rewards, next_states, dones = self.replay_buffer.sample_buffer(batch_size=self.batch_size)
        
        # convert batchs from 2D numpy arrays to tensorflow tensors
        states = tf.convert_to_tensor(states, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
        
        # expand rewards and dones from 1D numpy arrays to 2D tensors and reshape them
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        rewards = tf.expand_dims(rewards, axis=0)
        rewards = tf.reshape(rewards, [self.batch_size, 1])
        dones = tf.convert_to_tensor(dones, dtype=tf.float32)
        dones = tf.expand_dims(dones, axis=0)
        dones = tf.reshape(dones, [self.batch_size, 1])
        
        
        ## Update critic networks Q1 & Q2
        with tf.GradientTape(persistent=True) as tape_Q:
            next_actions, next_log_pi = self.policy_net(next_states)
            Q1_next = self.target_q_net1(next_states, next_actions)
            Q2_next = self.target_q_net2(next_states, next_actions)
            next_q_target = tf.minimum(Q1_next, Q2_next) - self.alpha * next_log_pi
            expected_q = tf.stop_gradient(rewards + (1 - dones) * self.gamma * next_q_target)
            
            curr_q1 = self.q_net1(states, actions)
            curr_q2 = self.q_net2(states, actions)
            
            q1_loss = tf.reduce_mean((curr_q1 - expected_q)**2)
            q2_loss = tf.reduce_mean((curr_q2 - expected_q)**2)  # tf.square()
            q_loss = q1_loss + q2_loss
        
        grad_Q1 = tape_Q.gradient(q_loss, self.q_net1.trainable_variables)
        grad_Q2 = tape_Q.gradient(q_loss, self.q_net2.trainable_variables)
        
        self.q_net1.optimizer.apply_gradients(zip(grad_Q1, self.q_net1.trainable_variables))
        self.q_net2.optimizer.apply_gradients(zip(grad_Q2, self.q_net2.trainable_variables))
        

        ## Update policy network and polyak update target Q networks less frequently (like in TD3 --> Delayed SAC)
        if self.update_step % self.policy_delay == 0:
            with tf.GradientTape() as tape_policy:
                new_actions, log_pi = self.policy_net(states)
                Q1 = self.q_net1(states, new_actions)
                Q2 = self.q_net2(states, new_actions)
                Q_min = tf.minimum(Q1, Q2)
                loss_policy = tf.reduce_mean(self.alpha * log_pi - Q_min)
            
            grad_policy = tape_policy.gradient(loss_policy, self.policy_net.trainable_variables)
            self.policy_net.optimizer.apply_gradients(zip(grad_policy, self.policy_net.trainable_variables))

            
            self.update_target_network_parameters()  # update target networks

        ## Update temperature
        with tf.GradientTape() as tape:
            _, log_pi_a = self.policy_net(states)
            alpha_loss = tf.reduce_mean(self.log_alpha*(-log_pi_a - self.minimum_entropy))
            
        grads = tape.gradient(alpha_loss, [self.log_alpha])
        self.alpha_optimizer.apply_gradients(zip(grads, [self.log_alpha]))
        self.alpha = tf.exp(self.log_alpha).numpy()

        self.update_step += 1  # Keep track of the number of network updates

# %%
def plot_learning_curve(scores, figure_file, Ylabel, color, avg_color=None , plot_folder='./plots', Xlabel='Episodes'):
    if not os.path.exists(plot_folder):
        os.makedirs(plot_folder)
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i - 100):i + 1])

    plt.figure()
    plt.plot(scores, color=color)
    if avg_color is not None:
        plt.plot(running_avg, color=avg_color)
    plt.xlabel(Xlabel)
    plt.ylabel(Ylabel)
    plt.savefig(figure_file)

# %%
n_games = 330

env = CartPoleBalance(max_force=40.0, max_phi=np.deg2rad(20), max_timesteps=500)  ## 200 funktioniert gut!

agent = Agent(env=env)

filename_return = '_SAC_' + 'return_' 
filename_alpha = '_SAC_' + 'alpha_' 
figure_file_return = 'plots/' + filename_return
figure_file_alpha = 'plots/' + filename_alpha

best_score = -100000.0
score_history = []
alpha_history = []

for i in range(n_games):
    score = 0.0
    steps = 0
    alpha = []
    done = False
    observation = env.reset()
    while not done:
        steps += 1
        action = agent.choose_action(observation)
        observation_, reward, done = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
        score += reward
        alpha.append(agent.alpha)

    score_history.append(score)
    alpha_history.append(np.mean(alpha))
    avg_score = np.mean(score_history[-100:])
    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()
    print('episode ', i, 'score %.1f' % score, 'avg score %1.f' % avg_score, 'steps ', steps, 'alpha ', np.mean(alpha))
    
plot_learning_curve(score_history, figure_file_return+'.png', color='lightgreen', avg_color='green', Ylabel='Return')
plot_learning_curve(alpha_history, figure_file_alpha+'.png', color='blue', Ylabel='Temperature alpha')

np.save(figure_file_return, score_history)
# Out:
# tf.Tensor(-1.0, shape=(), dtype=float32)
# Minimum Entropy set to:  tf.Tensor(-1.0, shape=(), dtype=float32)
# alpha:  [1.]
# ...save models...
# episode  0 score -29.1 avg score -29 steps  32 alpha  1.0
# episode  1 score -44.9 avg score -37 steps  34 alpha  1.0
# episode  2 score -62.1 avg score -45 steps  21 alpha  1.0
# episode  3 score -24.5 avg score -40 steps  18 alpha  1.0
# episode  4 score -89.0 avg score -50 steps  14 alpha  1.0
# episode  5 score -22.5 avg score -45 steps  28 alpha  1.0
# episode  6 score -25.1 avg score -42 steps  23 alpha  1.0
# episode  7 score -43.3 avg score -43 steps  15 alpha  1.0
# episode  8 score -40.5 avg score -42 steps  12 alpha  1.0
# episode  9 score -119.1 avg score -50 steps  44 alpha  1.0
# Buffer Size equals batch Size! - Learning begins :)
# episode  10 score -27.7 avg score -48 steps  22 alpha  0.9996185
# episode  11 score -17.6 avg score -45 steps  23 alpha  0.9943114
# episode  12 score -60.4 avg score -47 steps  25 alpha  0.9871674
# episode  13 score -28.8 avg score -45 steps  25 alpha  0.9797833
# episode  14 score -24.0 avg score -44 steps  33 alpha  0.9713167
# episode  15 score -57.3 avg score -45 steps  33 alpha  0.96183336
# episode  16 score -35.7 avg score -44 steps  14 alpha  0.95516485
# episode  17 score -29.5 avg score -43 steps  26 alpha  0.949531
# episode  18 score -28.7 avg score -43 steps  20 alpha  0.94310826
# episode  19 score -80.8 avg score -45 steps  71 alpha  0.93109375
# episode  20 score -26.7 avg score -44 steps  26 alpha  0.91902745
# episode  21 score -5.7 avg score -42 steps  36 alpha  0.91197085
# episode  22 score -22.6 avg score -41 steps  22 alpha  0.905793
# episode  23 score -53.3 avg score -42 steps  28 alpha  0.9005393
# episode  24 score -23.6 avg score -41 steps  17 alpha  0.89593774
# episode  25 score -53.3 avg score -41 steps  50 alpha  0.88924026
# episode  26 score -63.1 avg score -42 steps  17 alpha  0.8825482
# episode  27 score -37.7 avg score -42 steps  33 alpha  0.8776578
# episode  28 score -16.1 avg score -41 steps  37 alpha  0.87094754
# episode  29 score -35.1 avg score -41 steps  15 alpha  0.86591643
# episode  30 score -0.9 avg score -40 steps  38 alpha  0.86090136
# episode  31 score -30.1 avg score -39 steps  23 alpha  0.8550167
# episode  32 score -44.3 avg score -39 steps  19 alpha  0.8509168
# episode  33 score -144.6 avg score -43 steps  42 alpha  0.84514236
# episode  34 score -21.8 avg score -42 steps  17 alpha  0.839404
# episode  35 score -17.6 avg score -41 steps  25 alpha  0.83521616
# episode  36 score -60.6 avg score -42 steps  17 alpha  0.83114105
# No warmup anymore!
# episode  37 score -0.7 avg score -41 steps  57 alpha  0.82411015
# episode  38 score 19.8 avg score -39 steps  64 alpha  0.8120185
# episode  39 score 1.3 avg score -38 steps  42 alpha  0.8011785
# episode  40 score 2.0 avg score -37 steps  51 alpha  0.7915657
# episode  41 score 26.5 avg score -36 steps  79 alpha  0.7779713
# episode  42 score -1.5 avg score -35 steps  39 alpha  0.7654783
# episode  43 score 4.4 avg score -34 steps  55 alpha  0.75584495
# episode  44 score -30.3 avg score -34 steps  61 alpha  0.743834
# episode  45 score -10.9 avg score -33 steps  71 alpha  0.7302919
# episode  46 score -9.2 avg score -33 steps  37 alpha  0.7192662
# episode  47 score 6.0 avg score -32 steps  64 alpha  0.7089642
# episode  48 score 35.8 avg score -31 steps  100 alpha  0.6924116
# episode  49 score -11.3 avg score -30 steps  42 alpha  0.67795926
# episode  50 score 6.5 avg score -30 steps  49 alpha  0.6688998
# episode  51 score -10.1 avg score -29 steps  42 alpha  0.65992403
# ...save models...
# episode  52 score 4.8 avg score -29 steps  64 alpha  0.6496489
# ...save models...
# episode  53 score 42.4 avg score -27 steps  119 alpha  0.63228154
# ...save models...
# episode  54 score 47.7 avg score -26 steps  116 alpha  0.61028355
# ...save models...
# episode  55 score 10.7 avg score -25 steps  87 alpha  0.5917129
# ...save models...
# episode  56 score 4.4 avg score -25 steps  49 alpha  0.5794562
# ...save models...
# episode  57 score 14.9 avg score -24 steps  63 alpha  0.5696328
# ...save models...
# episode  58 score -3.8 avg score -24 steps  46 alpha  0.5601822
# ...save models...
# episode  59 score -4.0 avg score -23 steps  61 alpha  0.5509868
# ...save models...
# episode  60 score -10.3 avg score -23 steps  54 alpha  0.5412149
# ...save models...
# episode  61 score 0.6 avg score -23 steps  48 alpha  0.5327623
# ...save models...
# episode  62 score 5.5 avg score -22 steps  58 alpha  0.5241167
# ...save models...
# episode  63 score -1.7 avg score -22 steps  51 alpha  0.51540995
# ...save models...
# episode  64 score -4.4 avg score -22 steps  57 alpha  0.5069747
# ...save models...
# episode  65 score 70.4 avg score -20 steps  144 alpha  0.49160725
# ...save models...
# episode  66 score -3.0 avg score -20 steps  52 alpha  0.47709638
# ...save models...
# episode  67 score -3.4 avg score -20 steps  54 alpha  0.46949977
# ...save models...
# episode  68 score 0.7 avg score -20 steps  51 alpha  0.46204537
# ...save models...
# episode  69 score -18.1 avg score -20 steps  41 alpha  0.45559952
# ...save models...
# episode  70 score 27.2 avg score -19 steps  78 alpha  0.44743806
# ...save models...
# episode  71 score -9.4 avg score -19 steps  45 alpha  0.43904245
# ...save models...
# episode  72 score 7.1 avg score -18 steps  61 alpha  0.43202364
# ...save models...
# episode  73 score 23.1 avg score -18 steps  75 alpha  0.42323345
# ...save models...
# episode  74 score 0.8 avg score -18 steps  54 alpha  0.41504872
# ...save models...
# episode  75 score 8.1 avg score -17 steps  58 alpha  0.40803072
# ...save models...
# episode  76 score 68.5 avg score -16 steps  130 alpha  0.39660314
# ...save models...
# episode  77 score 6.7 avg score -16 steps  54 alpha  0.3857389
# ...save models...
# episode  78 score 128.1 avg score -14 steps  207 alpha  0.37113097
# ...save models...
# episode  79 score 3.2 avg score -14 steps  60 alpha  0.35678127
# ...save models...
# episode  80 score 30.7 avg score -13 steps  81 alpha  0.34943554
# ...save models...
# episode  81 score 0.3 avg score -13 steps  66 alpha  0.3419998
# ...save models...
# episode  82 score 5.4 avg score -13 steps  93 alpha  0.3342259
# ...save models...
# episode  83 score 64.7 avg score -12 steps  113 alpha  0.32444134
# ...save models...
# episode  84 score 36.1 avg score -11 steps  135 alpha  0.3131755
# ...save models...
# episode  85 score 22.4 avg score -11 steps  67 alpha  0.3043002
# ...save models...
# episode  86 score 31.2 avg score -10 steps  112 alpha  0.2967007
# ...save models...
# episode  87 score 4.0 avg score -10 steps  76 alpha  0.2888514
# ...save models...
# episode  88 score 112.8 avg score -9 steps  170 alpha  0.27898887
# ...save models...
# episode  89 score 5.1 avg score -9 steps  72 alpha  0.26966226
# ...save models...
# episode  90 score 94.7 avg score -8 steps  147 alpha  0.261577
# ...save models...
# episode  91 score 31.1 avg score -7 steps  77 alpha  0.25359294
# ...save models...
# episode  92 score 145.0 avg score -6 steps  208 alpha  0.2438228
# ...save models...
# episode  93 score 32.5 avg score -5 steps  90 alpha  0.23399478
# ...save models...
# episode  94 score 221.2 avg score -3 steps  304 alpha  0.2218629
# ...save models...
# episode  95 score 85.9 avg score -2 steps  146 alpha  0.20872821
# ...save models...
# episode  96 score 145.1 avg score -0 steps  210 alpha  0.19907434
# episode  97 score -0.5 avg score -0 steps  74 alpha  0.19169784
# ...save models...
# episode  98 score 43.2 avg score 0 steps  127 alpha  0.1867071
# ...save models...
# episode  99 score 45.4 avg score 1 steps  145 alpha  0.18016997
# ...save models...
# episode  100 score 59.5 avg score 1 steps  171 alpha  0.17291215
# ...save models...
# episode  101 score 6.9 avg score 2 steps  81 alpha  0.16728969
# ...save models...
# episode  102 score 6.7 avg score 3 steps  79 alpha  0.16380191
# ...save models...
# episode  103 score 124.2 avg score 4 steps  230 alpha  0.15727367
# ...save models...
# episode  104 score 77.9 avg score 6 steps  204 alpha  0.14863265
# ...save models...
# episode  105 score 27.0 avg score 6 steps  146 alpha  0.14204049
# ...save models...
# episode  106 score 41.8 avg score 7 steps  120 alpha  0.13724488
# ...save models...
# episode  107 score 27.5 avg score 8 steps  151 alpha  0.13248251
# ...save models...
# episode  108 score 30.8 avg score 8 steps  110 alpha  0.12802975
# ...save models...
# episode  109 score 105.5 avg score 11 steps  219 alpha  0.122704335
# ...save models...
# episode  110 score 82.8 avg score 12 steps  184 alpha  0.116350114
# ...save models...
# episode  111 score 142.7 avg score 13 steps  277 alpha  0.10952
# ...save models...
# episode  112 score 75.4 avg score 15 steps  193 alpha  0.10306176
# ...save models...
# episode  113 score 36.9 avg score 15 steps  137 alpha  0.09877996
# ...save models...
# episode  114 score -2.1 avg score 16 steps  159 alpha  0.09510153
# ...save models...
# episode  115 score 38.6 avg score 17 steps  168 alpha  0.091229275
# ...save models...
# episode  116 score 76.3 avg score 18 steps  208 alpha  0.08709526
# ...save models...
# episode  117 score 93.7 avg score 19 steps  212 alpha  0.08276227
# ...save models...
# episode  118 score 217.9 avg score 21 steps  366 alpha  0.07719609
# ...save models...
# episode  119 score 10.6 avg score 22 steps  143 alpha  0.0725773
# ...save models...
# episode  120 score 10.9 avg score 23 steps  122 alpha  0.07032827
# ...save models...
# episode  121 score 297.7 avg score 26 steps  500 alpha  0.06563124
# ...save models...
# episode  122 score 139.4 avg score 27 steps  304 alpha  0.06019142
# ...save models...
# episode  123 score 178.6 avg score 30 steps  284 alpha  0.05663262
# ...save models...
# episode  124 score 266.0 avg score 32 steps  469 alpha  0.052585155
# ...save models...
# episode  125 score 19.0 avg score 33 steps  218 alpha  0.04929253
# ...save models...
# episode  126 score 117.1 avg score 35 steps  374 alpha  0.04683099
# ...save models...
# episode  127 score 26.6 avg score 36 steps  122 alpha  0.044953212
# ...save models...
# episode  128 score 539.4 avg score 41 steps  500 alpha  0.04269767
# ...save models...
# episode  129 score 81.0 avg score 42 steps  181 alpha  0.040328067
# ...save models...
# episode  130 score 497.1 avg score 47 steps  500 alpha  0.038449317
# ...save models...
# episode  131 score 105.8 avg score 49 steps  198 alpha  0.03667526
# ...save models...
# episode  132 score 548.5 avg score 55 steps  500 alpha  0.034889486
# ...save models...
# episode  133 score 536.2 avg score 61 steps  500 alpha  0.03340235
# ...save models...
# episode  134 score 525.1 avg score 67 steps  500 alpha  0.032599512
# ...save models...
# episode  135 score 346.6 avg score 71 steps  471 alpha  0.0319411
# ...save models...
# episode  136 score 517.1 avg score 76 steps  500 alpha  0.031459123
# ...save models...
# episode  137 score 534.1 avg score 82 steps  500 alpha  0.03151193
# ...save models...
# episode  138 score 528.0 avg score 87 steps  500 alpha  0.0318524
# ...save models...
# episode  139 score 540.9 avg score 92 steps  500 alpha  0.031252336
# ...save models...
# episode  140 score 534.3 avg score 97 steps  500 alpha  0.03099407
# ...save models...
# episode  141 score 550.0 avg score 103 steps  500 alpha  0.030838158
# ...save models...
# episode  142 score 525.9 avg score 108 steps  500 alpha  0.031393357
# ...save models...
# episode  143 score 543.7 avg score 113 steps  500 alpha  0.031692028
# ...save models...
# episode  144 score 550.6 avg score 119 steps  500 alpha  0.03151906
# ...save models...
# episode  145 score 548.6 avg score 125 steps  500 alpha  0.031426385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4f1a97117b7a> in <module>()
#      22     while not done:
#      23         steps += 1
# ---> 24         action = agent.choose_action(observation)
#      25         observation_, reward, done = env.step(action)
#      26         agent.remember(observation, action, reward, observation_, done)
#
# <ipython-input-6-673c7d175349> in choose_action(self, state)
#      80             state = tf.convert_to_tensor(state, dtype=tf.float32)
#      81             state = tf.expand_dims(state, axis=0)
# ---> 82             actions, _ = self.policy_net(state)
#      83
#      84         self.time_step += 1
#
# C:\Users\marku\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-5-25dc97030ed1> in call(self, state)
#      59         x = self.fc1(state)
#      60         x = self.fc2(x)
# ---> 61         mu = self.mu(x)
#      62
#      63         log_std = self.log_std(x)
#
# C:\Users\marku\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# C:\Users\marku\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\layers\core.py in call(self, inputs)
#    1140         outputs = sparse_ops.sparse_tensor_dense_matmul(inputs, self.kernel)
#    1141       else:
# -> 1142         outputs = gen_math_ops.mat_mul(inputs, self.kernel)
#    1143     if self.use_bias:
#    1144       outputs = nn.bias_add(outputs, self.bias)
#
# C:\Users\marku\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5603         _ctx._context_handle, tld.device_name, "MatMul", name,
#    5604         tld.op_callbacks, a, b, "transpose_a", transpose_a, "transpose_b",
# -> 5605         transpose_b)
#    5606       return _result
#    5607     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
x = []
dx = []
phi = []
dphi = []
force = []

for i in range(1):
    observation = env.reset()
    done = False
    while not done:
        x.append(observation[0])
        phi.append(np.rad2deg(observation[1]))
        dx.append(observation[2])
        dphi.append(observation[3])
        action = agent.choose_action(observation)
        force.append(action)
        observation_, reward, done = env.step(action)
        observation = observation_
    
n_steps = len(x)
t = [env.dt*i for i in range(n_steps)]

plt.plot(t, phi, label='phi', color='green')
plt.title('pole angle')
plt.ylabel('phi [deg]')
plt.xlabel('time [s]')
plt.legend()
plt.show()

plt.plot(t, x, label='x')
plt.title('cart distance')
plt.ylabel('x [m]')
plt.xlabel('time [s]')
plt.legend()
plt.show()

plt.plot(t, dx, label='dx')
plt.plot(t, dphi, label='dphi')
plt.title('velocities')
plt.ylabel('dx [m/s]   dphi [rad/s]')
plt.xlabel('time [s]')
plt.legend()
plt.show()

plt.plot(t, force)
plt.title('horizontal force on cart')
plt.ylabel('F [N]')
plt.xlabel('time [s]')
plt.show()

# %%
def angle_normalize(x):
    return (((x+np.pi) % (2*np.pi)) - np.pi)  # for swingup

# %%
#env = CartPoleBalance(max_force=40.0, max_phi=np.deg2rad(20))  ## 200 funktioniert gut!
for i in range(2):
    done = False
    observation = env.reset()
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done = env.step(action)
        observation = observation_
        env.render()
env.close()

# %%
from IPython import display
env.reset()
plt.imshow(env.render(mode='rgb_array'))
display.display(plt.gcf())    
display.clear_output(wait=True)
env.close()
