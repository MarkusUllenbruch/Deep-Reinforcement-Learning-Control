# %% [markdown]
# # Stabilize Inverted Cartpole with Deep Reinforcement Learning

# %% [markdown]
# In this notebook the environment of a double inverted cartpole is implemented.
# The pendulum starts in a state very close to the unstable equilibrium $\theta_1, \theta_2 \approx 0$.
# The goal is to create a reinforcement learning agent which will stabilize the cartpole in this inverted position. The trained neural network of the agent will observe the state $s_t$ of the physical system and will output the horizontal Force $f_t$ acting on the cart to control the double cartpole system.
# No classical control theory will be used to achieve this.

# %% [markdown]
# ## 1. Double Cartpole Environment

# %% [markdown]
# ![Double-inverted-pendulum-on-a-cart.png](attachment:Double-inverted-pendulum-on-a-cart.png)

# %% [markdown]
# Quelle: Alexander Bogdanov - Optimal Control of a Double Inverted Pendulum on a Cart
#
# https://www.researchgate.net/figure/Double-inverted-pendulum-on-a-cart_fig1_250107215

# %%
import numpy as np
from math import sin, cos
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
class CartPoleBalance:
    def __init__(self, max_force, max_timesteps):
        self.state = None
        self.max_speed = 12.0 # [m/s], [rad/s]
        self.max_x = 3.0
        self.max_force = max_force # [N]
        self.max_timesteps = max_timesteps
        
        self.action_space_low = np.array([-self.max_force])
        self.action_space_high = np.array([self.max_force])
        
        self.observation_space_high = np.array([self.max_x, 1.0, 1.0, 1.0, 1.0, self.max_speed, self.max_speed, self.max_speed])
        self.observation_space_low = - np.array([self.max_x, -1.0, -1.0, -1.0, -1.0, self.max_speed, self.max_speed, self.max_speed])
        
        self.dt = 0.02
        self.steps = 0
        
        self.viewer = None
        self.state=None
    
    def step(self, action):
        self.steps += 1
        q, theta1, theta2, dq, dtheta1, dtheta2 = self.state
        
        # force is bounded due to maximum motor torque of actuator
        F = np.clip(action, -self.max_force, self.max_force)[0]
        
        x0 = [q, theta1, theta2, dq, dtheta1, dtheta2]
        integration_timesteps = np.linspace(0, self.dt, 8)
        X = odeint(self.cartpole_dXdt, x0, integration_timesteps, args=(F,))
        
        # pick last elements of trajectory
        q = X[-1, 0]  
        theta1 = X[-1, 1]
        theta2 = X[-1, 2]
        dq = X[-1, 3]
        dtheta1 = X[-1, 4]
        dtheta2 = X[-1, 5]
        
        self.state = (q, theta1, theta2, dq, dtheta1, dtheta2)
        
        # epsidoe ends when done = True
        done = bool(
            q < -self.max_x
            or q > self.max_x
            or self.steps >= self.max_timesteps)
        
        # reward function of transition s_t, action --> s_t+1
        
        #theta1 = self.wrap2pi(theta1)
        #theta2 = self.wrap2pi(theta2)
        
        reward = 1.0 + cos(theta1) + cos(theta2)
            
        # Swing up: https://ww2.mathworks.cn/help/reinforcement-learning/ug/train-ddpg-agent-to-swing-up-and-balance-cart-pole-system.html
        
        return self.get_obs(), reward, done
    
    def get_obs(self):
        q, theta1, theta2, dq, dtheta1, dtheta2 = self.state
        return np.array([q, sin(theta1), cos(theta1), sin(theta2), cos(theta2), dq, dtheta1, dtheta2])
        
        
    
    def cartpole_dXdt(self, X, t, u):
        m, m1, m2 = 0.6, 0.853, 0.51
        g = 9.81
        d1, d2, d3 = 0.003, 0.003, 0.003
        l1, l2 = 0.35, 0.48
        
        q, theta1, theta2, dq, dtheta1, dtheta2 = X
    
        ddq = ((2*l1*l2*m1*u + l1*l2*m2*u - d2*dtheta1*l2*m2*cos(theta1 - 2*theta2) + 2*dtheta1**2*l1**2*l2*m1**2*sin(theta1) 
            -d3*dtheta2*l1*m1*cos(2*theta1 - theta2) - d3*dtheta2*l1*m2*cos(2*theta1 - theta2) - 2*d1*dq*l1*l2*m1 
            -d1*dq*l1*l2*m2 - l1*l2*m2*u*cos(2*theta1 - 2*theta2) - g*l1*l2*m1**2*sin(2*theta1) 
            +2*d2*dtheta1*l2*m1*cos(theta1) + d2*dtheta1*l2*m2*cos(theta1) + d3*dtheta2*l1*m1*cos(theta2) 
            +d3*dtheta2*l1*m2*cos(theta2) + 2*dtheta1**2*l1**2*l2*m1*m2*sin(theta1) + dtheta2**2*l1*l2**2*m1*m2*sin(theta2)
            +dtheta2**2*l1*l2**2*m1*m2*sin(2*theta1 - theta2) - g*l1*l2*m1*m2*sin(2*theta1) 
            + d1*dq*l1*l2*m2*cos(2*theta1 - 2*theta2))/(l1*l2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + m1**2 
                                                               - m1*m2*cos(2*theta1) - m*m2*cos(2*theta1 - 2*theta2))))
    
        ddtheta1 =  (-(2*d2*dtheta1*l2*m + 2*d2*dtheta1*l2*m1 + d2*dtheta1*l2*m2 - 2*d3*dtheta2*l1*m*cos(theta1 - theta2) -
                   d3*dtheta2*l1*m1*cos(theta1 - theta2) - d3*dtheta2*l1*m2*cos(theta1 - theta2) - 
                   l1*l2*m2*u*cos(theta1 -2*theta2) - d2*dtheta1*l2*m2*cos(2*theta2) - 2*g*l1*l2*m1**2*sin(theta1) 
                   + dtheta1**2*l1**2*l2*m1**2*sin(2*theta1) + d3*dtheta2*l1*m1*cos(theta1 + theta2) + 
                   d3*dtheta2*l1*m2*cos(theta1 + theta2) + 2*l1*l2*m1*u*cos(theta1) + l1*l2*m2*u*cos(theta1) - 
                   2*d1*dq*l1*l2*m1*cos(theta1) - d1*dq*l1*l2*m2*cos(theta1) + 
                   2*dtheta2**2*l1*l2**2*m*m2*sin(theta1 - theta2) + dtheta2**2*l1*l2**2*m1*m2*sin(theta1 - theta2) - 
                   2*g*l1*l2*m*m1*sin(theta1) - g*l1*l2*m*m2*sin(theta1) - 2*g*l1*l2*m1*m2*sin(theta1) + 
                   d1*dq*l1*l2*m2*cos(theta1 - 2*theta2) + dtheta1**2*l1**2*l2*m1*m2*sin(2*theta1) - 
                   g*l1*l2*m*m2*sin(theta1 - 2*theta2) + dtheta1**2*l1**2*l2*m*m2*sin(2*theta1 - 2*theta2) + 
                   dtheta2**2*l1*l2**2*m1*m2*sin(theta1 + theta2))/(l1**2*l2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + 
                                                            m1**2 - m1*m2*cos(2*theta1) - m*m2*cos(2*theta1 - 2*theta2))))
    
        ddtheta2 =((d2*dtheta1*l2*m2**2*cos(theta1 - theta2) - d3*dtheta2*l1*m2**2 - d2*dtheta1*l2*m2**2*cos(theta1 + theta2) -
                l1*l2*m2**2*u*cos(theta2) - d3*dtheta2*l1*m1**2 - 2*d3*dtheta2*l1*m*m1 - 2*d3*dtheta2*l1*m*m2 -
                2*d3*dtheta2*l1*m1*m2 + d3*dtheta2*l1*m1**2*cos(2*theta1) + d3*dtheta2*l1*m2**2*cos(2*theta1) +
                l1*l2*m2**2*u*cos(2*theta1 - theta2) + dtheta2**2*l1*l2**2*m*m2**2*sin(2*theta1 - 2*theta2) -
                d2*dtheta1*l2*m1*m2*cos(theta1 + theta2) - d1*dq*l1*l2*m2**2*cos(2*theta1 - theta2) -
                g*l1*l2*m*m2**2*sin(2*theta1 - theta2) - l1*l2*m1*m2*u*cos(theta2) + 2*d2*dtheta1*l2*m*m2*cos(theta1 - theta2)
                + d2*dtheta1*l2*m1*m2*cos(theta1 - theta2) + d1*dq*l1*l2*m2**2*cos(theta2) + 2*d3*dtheta2*l1*m1*m2*cos(2*theta1)
                + 2*dtheta1**2*l1**2*l2*m*m2**2*sin(theta1 - theta2) + g*l1*l2*m*m2**2*sin(theta2) +
                l1*l2*m1*m2*u*cos(2*theta1 - theta2) - d1*dq*l1*l2*m1*m2*cos(2*theta1 - theta2) -
                g*l1*l2*m*m1*m2*sin(2*theta1 - theta2) + d1*dq*l1*l2*m1*m2*cos(theta2)
                +2*dtheta1**2*l1**2*l2*m*m1*m2*sin(theta1 - theta2) + g*l1*l2*m*m1*m2*sin(theta2))
               /(l1*l2**2*m2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + m1**2 - m1*m2*cos(2*theta1)
                              - m*m2*cos(2*theta1 - 2*theta2))))
        
        return float(dq), float(dtheta1), float(dtheta2), float(ddq), float(ddtheta1), float(ddtheta2)
    
    def reset(self):
        #start_deg = 180
        self.steps = 0
        #high = np.array([0.1, np.deg2rad(start_deg), np.deg2rad(start_deg), 0.001, 0.001, 0.001]) # q, theta1, theta2, dq, dtheta1, dtheta2
        #self.state = np.random.uniform(low=-high, high=high)
        self.state = (0.0, np.deg2rad(180), np.deg2rad(180), 0.0, 0.0, 0.0) ##########################
        return self.get_obs()
    
    def wrap2pi(self, x):
        return (((x+np.pi) % (2*np.pi)) - np.pi)  
    
    def render(self, mode='human'):
        screen_width = 600
        screen_height = 600

        world_width = self.max_x * 2
        scale = screen_width/world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (2 * 0.42)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            from gym.envs.classic_control import rendering
            self.viewer = rendering.Viewer(screen_width, screen_height)
            
            
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            
            l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
            pole = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(.8, .6, .4)
            self.poletrans = rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            
            l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
            pole2 = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole2.set_color(.2, .6, .4)
            self.poletrans2 = rendering.Transform(translation=(0, polelen))
            pole2.add_attr(self.poletrans2)
            pole2.add_attr(self.poletrans)
            pole2.add_attr(self.carttrans)
            self.viewer.add_geom(pole2)
            
            
            self.axle = rendering.make_circle(polewidth/2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(.5, .5, .8)
            self.viewer.add_geom(self.axle)
            
            self.axle = rendering.make_circle(polewidth/2)
            self.axle.add_attr(self.poletrans2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(.5, .5, .8)
            self.viewer.add_geom(self.axle)
            
            
            self.track = rendering.Line((0, 3*carty), (screen_width, 3*carty))  #4*
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole
            self._pole_geom2 = pole2

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
        pole.v = [(l, b), (l, t), (r, t), (r, b)]
        
        pole2 = self._pole_geom2
        l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
        pole2.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, 3*carty)
        self.poletrans.set_rotation(-x[1])
        self.poletrans2.set_rotation(-x[2]+x[1])

        return self.viewer.render(return_rgb_array=mode == 'rgb_array')

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %% [markdown]
# ## 2. Deep Reinforcement Learning Agent - Soft Actor-Critic (SAC)
#
# Implementation of newest style of SAC with two Q Networks and temperature parameter alpha optimization/tuning.

# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow_probability as tfp  # Distributions with reparam trick to gradients flow through
from tensorflow.keras.layers import Dense
from tensorflow.keras import initializers  # for layer weight initializing
import tensorflow.keras.losses as losses
import gym
import pybullet_envs
import matplotlib.pyplot as plt

# %%
class ReplayBuffer:
    def __init__(self, n_actions, input_shape, max_size=1000000):
        self.mem_size = max_size

        self.state_memory = np.zeros((self.mem_size, input_shape))
        self.new_state_memory = np.zeros((self.mem_size, input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

        self.n_count = 0

    def store_transition(self, state, action, reward, state_, done):
        index = self.n_count % self.mem_size

        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done

        self.n_count += 1

    def sample_buffer(self, batch_size=256):
        max_mem = min(self.n_count, self.mem_size)
        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

# %%
class CriticNetwork(tf.keras.Model):
    def __init__(self, n_states, n_actions, fc1_dims, fc2_dims, network_name, chkpt_dir='tmp/SAC', init_w=3e-3):
        super(CriticNetwork, self).__init__()

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')

        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states + n_actions, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        self.q = Dense(units=1,
                       kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w), # Änderung
                       bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))

    def call(self, state, action):
        inputs = tf.concat([state, action], axis=1)
        x = self.fc1(inputs)
        x = self.fc2(x)
        return self.q(x) 


class ActorNetwork(tf.keras.Model):
    def __init__(self,
                 n_states,
                 n_actions,
                 fc1_dims,
                 fc2_dims,
                 network_name,
                 chkpt_dir='tmp/SAC',
                 init_w=3e-3,
                 log_std_min=-20,
                 log_std_max=2):
        super(ActorNetwork, self).__init__()
        
        self.log_std_min = log_std_min
        self.log_std_max = log_std_max

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')
        
        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        
        self.mu = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        
        self.log_std = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        

    def call(self, state):
        x = self.fc1(state)
        x = self.fc2(x)
        mu = self.mu(x)
        
        log_std = self.log_std(x)
        log_std = tf.clip_by_value(log_std, clip_value_min=self.log_std_min, clip_value_max=self.log_std_max)
        std = tf.exp(log_std)
        
        normal = tfp.distributions.Normal(mu, std)  # make Gaussian distribution of mu, and sigma for actions
        
        z = normal.sample()  # sample from distribution with reparam trick
        action = tf.tanh(z)  # bound actions to [-1, +1]
        
        # correct log_probs because of bounding the actions
        log_prob = normal.log_prob(z) - tf.math.log(1 - tf.math.square(action) + 1e-6)  # Ist dasselbe!
        log_prob = tf.reduce_sum(log_prob, axis=1, keepdims=True) # tf.reduce_sum() or tf.reduce_mean()

        return action, log_prob, mu

# %%
class Agent:
    """ 2019 State-of-the-Art Implementation of SAC with optimized temperature

    """
    def __init__(self,
                 env,
                 lr_Q = 3e-4,
                 lr_actor = 3e-4,
                 lr_a = 3e-4,
                 gamma=0.99,
                 tau=0.005,
                 layer1_size=256,
                 layer2_size=256,
                 batch_size=256,
                 max_size=1000000,
                 warmup=1000,
                 policy_delay=1,
                 minimum_entropy=None):

        self.env = env
        self.action_range = [env.action_space_low, env.action_space_high]

        self.n_states = env.observation_space_low.shape[0]
        self.n_actions = env.action_space_low.shape[0]

        self.min_action = env.action_space_low
        self.max_action = env.action_space_high

        self.gamma = gamma
        self.tau = tau
        self.batch_size = batch_size
        self.warmup = warmup
        self.time_step = 0
        self.update_step = 0
        self.policy_delay = policy_delay

        self.policy_net = ActorNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                       fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Actor')

        self.q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_1')

        self.q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_2')

        self.target_q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_1')

        self.target_q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_2')

        self.replay_buffer = ReplayBuffer(n_actions=self.n_actions,
                                          input_shape=self.n_states,
                                          max_size=max_size)
        
        self.policy_net.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_actor))
        self.q_net1.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))
        self.q_net2.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))

        self.update_target_network_parameters(tau=1)  # copy parameters to target networks

        # entropy temperature parameter alpha
        #self.log_alpha = tf.Variable(0.0, dtype=tf.float32)
        print(-tf.constant(env.action_space_low.shape[0], dtype=tf.float32))
        
        self.log_alpha = tf.Variable(tf.zeros(1), trainable=True)
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32))
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32)) if minimum_entropy is None else minimum_entropy
        print('Minimum Entropy set to: ', self.minimum_entropy)
        self.alpha_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_a)
        self.alpha = tf.exp(self.log_alpha).numpy()
        print('alpha: ', self.alpha)
        

    def choose_action(self, state):
        if self.time_step < self.warmup:
            actions = np.random.uniform(low=-1.0, high=1.0, size=self.n_actions)  # "random uniform distribution over all valid actions"
            actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        else:
            state = tf.convert_to_tensor(state, dtype=tf.float32)
            state = tf.expand_dims(state, axis=0)
            actions, _, _ = self.policy_net(state)

        self.time_step += 1
        if self.time_step == self.warmup:
            print('No warmup anymore!')
        a = self.rescale_action(actions[0].numpy())
        return a
    
    def control(self, state):
        state = tf.convert_to_tensor(state, dtype=tf.float32)
        state = tf.expand_dims(state, axis=0)
        _, _, mu = self.policy_net(state)
        return self.rescale_action(mu[0].numpy())

    def scale_action(self, action):
        """ Scale all actions to [-1., +1.]

        :param action: unscaled actions
        :return: scaled actions all in range -1. .. +1.
        """
        #old = 2 * (action - self.min_action) / (self.max_action - self.min_action) - 1.0
        scale = (2 * action - (self.action_range[1] + self.action_range[0])) / (self.action_range[1] - self.action_range[0])
        return scale

    def rescale_action(self, action):
        """ Rescale all scaled actions to environment actionspace values

        :param action: scaled actions
        :return: rescaled actions all in range min_action .. max_action
        """
        #old = (action + 1.0) * (self.max_action - self.min_action) / 2.0 + self.min_action
        rescale = action * (self.action_range[1] - self.action_range[0]) / 2.0 + \
               (self.action_range[1] + self.action_range[0]) / 2.0
        return rescale

    def remember(self, state, action, reward, new_state, done):
        action = self.scale_action(action)  # ÄNDERUNG! Funktioniert das mit?
        self.replay_buffer.store_transition(state, action, reward, new_state, done)

    def update_target_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau
        
        weights = []
        for theta_target, theta in zip(self.target_q_net1.get_weights(), 
                                       self.q_net1.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net1.set_weights(weights)
        
        weights = []
        for theta_target, theta in zip(self.target_q_net2.get_weights(),
                                       self.q_net2.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net2.set_weights(weights)
        
        #weights = []
        #theta_target = self.target_q_net1.weights
        #for i, theta in enumerate(self.q_net1.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net1.set_weights(weights)
        # 
        #weights = []
        #theta_target = self.target_q_net2.weights
        #for i, theta in enumerate(self.q_net2.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net2.set_weights(weights)
        

    def save_models(self):
        print('...save actor...')
        self.policy_net.save_weights('./Actor')

    def load_models(self):
        self.policy_net.load_weights('./Actor')

    def learn(self):
        if self.replay_buffer.n_count < self.batch_size:
            return
        elif self.replay_buffer.n_count == self.batch_size:
            print('Buffer Size equals batch Size! - Learning begins :)')
            return
        
        # sample batch from replay buffer
        states, actions, rewards, next_states, dones = self.replay_buffer.sample_buffer(batch_size=self.batch_size)
        
        # convert batchs from 2D numpy arrays to tensorflow tensors
        states = tf.convert_to_tensor(states, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
        
        # expand rewards and dones from 1D numpy arrays to 2D tensors and reshape them
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        rewards = tf.expand_dims(rewards, axis=0)
        rewards = tf.reshape(rewards, [self.batch_size, 1])
        dones = tf.convert_to_tensor(dones, dtype=tf.float32)
        dones = tf.expand_dims(dones, axis=0)
        dones = tf.reshape(dones, [self.batch_size, 1])
        
        
        ## Update critic networks Q1 & Q2
        with tf.GradientTape(persistent=True) as tape_Q:
            next_actions, next_log_pi, _ = self.policy_net(next_states)
            Q1_next = self.target_q_net1(next_states, next_actions)
            Q2_next = self.target_q_net2(next_states, next_actions)
            next_q_target = tf.minimum(Q1_next, Q2_next) - self.alpha * next_log_pi
            expected_q = tf.stop_gradient(rewards + (1 - dones) * self.gamma * next_q_target)
            
            curr_q1 = self.q_net1(states, actions)
            curr_q2 = self.q_net2(states, actions)
            
            q1_loss = tf.reduce_mean((curr_q1 - expected_q)**2)
            q2_loss = tf.reduce_mean((curr_q2 - expected_q)**2)  # tf.square()
            q_loss = q1_loss + q2_loss
        
        grad_Q1 = tape_Q.gradient(q_loss, self.q_net1.trainable_variables)
        grad_Q2 = tape_Q.gradient(q_loss, self.q_net2.trainable_variables)
        
        self.q_net1.optimizer.apply_gradients(zip(grad_Q1, self.q_net1.trainable_variables))
        self.q_net2.optimizer.apply_gradients(zip(grad_Q2, self.q_net2.trainable_variables))
        

        ## Update policy network and polyak update target Q networks less frequently (like in TD3 --> Delayed SAC)
        if self.update_step % self.policy_delay == 0:
            with tf.GradientTape() as tape_policy:
                new_actions, log_pi, _ = self.policy_net(states)
                Q1 = self.q_net1(states, new_actions)
                Q2 = self.q_net2(states, new_actions)
                Q_min = tf.minimum(Q1, Q2)
                loss_policy = tf.reduce_mean(self.alpha * log_pi - Q_min)
            
            grad_policy = tape_policy.gradient(loss_policy, self.policy_net.trainable_variables)
            self.policy_net.optimizer.apply_gradients(zip(grad_policy, self.policy_net.trainable_variables))

            
            self.update_target_network_parameters()  # update target networks

        ## Update temperature
        with tf.GradientTape() as tape:
            _, log_pi_a, _ = self.policy_net(states)
            alpha_loss = tf.reduce_mean(self.log_alpha*(-log_pi_a - self.minimum_entropy))
            
        grads = tape.gradient(alpha_loss, [self.log_alpha])
        self.alpha_optimizer.apply_gradients(zip(grads, [self.log_alpha]))
        self.alpha = tf.exp(self.log_alpha).numpy()

        self.update_step += 1  # Keep track of the number of network updates

# %%
def plot_learning_curve(scores, figure_file, Ylabel, color, avg_color=None , plot_folder='./plots', Xlabel='Episodes'):
    if not os.path.exists(plot_folder):
        os.makedirs(plot_folder)
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i - 100):i + 1])

    plt.figure()
    plt.plot(scores, color=color)
    if avg_color is not None:
        plt.plot(running_avg, color=avg_color)
    plt.xlabel(Xlabel)
    plt.ylabel(Ylabel)
    plt.savefig(figure_file)

# %%
n_games = 3000

env = CartPoleBalance(max_force=40.0, max_timesteps=600)  ## 200 funktioniert gut!

agent = Agent(env=env, warmup=1000)

filename_return = '_SAC_' + 'return_' 
filename_alpha = '_SAC_' + 'alpha_' 
figure_file_return = 'plots/' + filename_return
figure_file_alpha = 'plots/' + filename_alpha

best_score = -100000.0
score_history = []
alpha_history = []

for i in range(n_games):
    score = 0.0
    steps = 0
    alpha = []
    done = False
    observation = env.reset()
    while not done:
        steps += 1
        action = agent.choose_action(observation)
        observation_, reward, done = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
        score += reward
        alpha.append(agent.alpha)

    score_history.append(score)
    alpha_history.append(np.mean(alpha))
    avg_score = np.mean(score_history[-100:])
    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()
    print('episode ', i, 'score %.1f' % score, 'avg score %1.f' % avg_score, 'steps ', steps, 'alpha ', np.mean(alpha))
    
plot_learning_curve(score_history, figure_file_return+'.png', color='lightgreen', avg_color='green', Ylabel='Return')
plot_learning_curve(alpha_history, figure_file_alpha+'.png', color='blue', Ylabel='Temperature alpha')

np.save(figure_file_return, score_history)
# Out:
# tf.Tensor(-1.0, shape=(), dtype=float32)
# Minimum Entropy set to:  tf.Tensor(-1.0, shape=(), dtype=float32)
# alpha:  [1.]
# ...save actor...
# episode  0 score -35.7 avg score -36 steps  88 alpha  1.0
# Buffer Size equals batch Size! - Learning begins :)
# ...save actor...
# episode  1 score 16.5 avg score -10 steps  357 alpha  0.985183
# episode  2 score -60.4 avg score -27 steps  80 alpha  0.9334346
# episode  3 score -59.9 avg score -35 steps  309 alpha  0.88079894
# No warmup anymore!
# episode  4 score -111.1 avg score -50 steps  297 alpha  0.80423135
# episode  5 score -39.5 avg score -48 steps  85 alpha  0.7592216
# episode  6 score -48.1 avg score -48 steps  92 alpha  0.73937285
# episode  7 score -7.9 avg score -43 steps  67 alpha  0.721981
# episode  8 score -4.2 avg score -39 steps  130 alpha  0.70106834
# episode  9 score 91.2 avg score -26 steps  286 alpha  0.6590383
# episode  10 score 47.9 avg score -19 steps  158 alpha  0.6167576
# episode  11 score 18.3 avg score -16 steps  118 alpha  0.5920478
# episode  12 score 8.6 avg score -14 steps  55 alpha  0.57710606
# episode  13 score 36.6 avg score -11 steps  75 alpha  0.5661841
# episode  14 score -6.4 avg score -10 steps  78 alpha  0.55365914
# episode  15 score -5.5 avg score -10 steps  82 alpha  0.5409265
# ...save actor...
# episode  16 score 2.0 avg score -9 steps  57 alpha  0.53017795
# episode  17 score -13.4 avg score -10 steps  54 alpha  0.52190274
# ...save actor...
# episode  18 score 52.9 avg score -6 steps  93 alpha  0.5111689
# ...save actor...
# episode  19 score 11.2 avg score -5 steps  55 alpha  0.50062674
# ...save actor...
# episode  20 score 18.4 avg score -4 steps  39 alpha  0.494124
# ...save actor...
# episode  21 score 18.9 avg score -3 steps  50 alpha  0.48808876
# ...save actor...
# episode  22 score 11.1 avg score -3 steps  41 alpha  0.4820126
# ...save actor...
# episode  23 score 72.9 avg score 1 steps  99 alpha  0.47296456
# ...save actor...
# episode  24 score 19.0 avg score 1 steps  31 alpha  0.46488282
# ...save actor...
# episode  25 score 62.7 avg score 4 steps  107 alpha  0.45649955
# ...save actor...
# episode  26 score 50.6 avg score 5 steps  97 alpha  0.44455153
# ...save actor...
# episode  27 score 12.3 avg score 6 steps  33 alpha  0.43726817
# ...save actor...
# episode  28 score 84.8 avg score 8 steps  98 alpha  0.43020043
# ...save actor...
# episode  29 score 11.1 avg score 8 steps  58 alpha  0.4220471
# ...save actor...
# episode  30 score 123.2 avg score 12 steps  111 alpha  0.4135705
# ...save actor...
# episode  31 score 17.4 avg score 12 steps  35 alpha  0.4064553
# ...save actor...
# episode  32 score 14.9 avg score 12 steps  40 alpha  0.4029994
# ...save actor...
# episode  33 score 65.6 avg score 14 steps  103 alpha  0.3964728
# ...save actor...
# episode  34 score 76.0 avg score 16 steps  131 alpha  0.3861268
# episode  35 score 12.8 avg score 16 steps  40 alpha  0.3787709
# ...save actor...
# episode  36 score 25.2 avg score 16 steps  58 alpha  0.37478262
# ...save actor...
# episode  37 score 25.0 avg score 16 steps  34 alpha  0.37106135
# ...save actor...
# episode  38 score 21.6 avg score 16 steps  31 alpha  0.36848575
# ...save actor...
# episode  39 score 22.2 avg score 16 steps  59 alpha  0.36495066
# episode  40 score 14.5 avg score 16 steps  40 alpha  0.36109716
# ...save actor...
# episode  41 score 22.6 avg score 17 steps  33 alpha  0.35827124
# ...save actor...
# episode  42 score 24.3 avg score 17 steps  36 alpha  0.35559312
# episode  43 score 16.7 avg score 17 steps  33 alpha  0.35302365
# ...save actor...
# episode  44 score 26.4 avg score 17 steps  34 alpha  0.35054007
# ...save actor...
# episode  45 score 44.6 avg score 18 steps  73 alpha  0.34652382
# ...save actor...
# episode  46 score 48.8 avg score 18 steps  72 alpha  0.34126568
# ...save actor...
# episode  47 score 21.2 avg score 18 steps  30 alpha  0.33762842
# ...save actor...
# episode  48 score 24.6 avg score 18 steps  33 alpha  0.33539847
# ...save actor...
# episode  49 score 23.3 avg score 19 steps  35 alpha  0.3329964
# ...save actor...
# episode  50 score 76.2 avg score 20 steps  96 alpha  0.32856885
# ...save actor...
# episode  51 score 90.8 avg score 21 steps  116 alpha  0.32154062
# ...save actor...
# episode  52 score 27.1 avg score 21 steps  34 alpha  0.31675515
# ...save actor...
# episode  53 score 129.8 avg score 23 steps  155 alpha  0.31064695
# episode  54 score 13.8 avg score 23 steps  48 alpha  0.30417725
# episode  55 score 22.1 avg score 23 steps  35 alpha  0.30163527
# episode  56 score 24.6 avg score 23 steps  34 alpha  0.2994596
# episode  57 score 25.5 avg score 23 steps  33 alpha  0.29738265
# episode  58 score 24.2 avg score 23 steps  34 alpha  0.29538432
# episode  59 score 23.9 avg score 23 steps  35 alpha  0.2933076
# episode  60 score 22.7 avg score 23 steps  31 alpha  0.29140058
# episode  61 score 27.7 avg score 23 steps  36 alpha  0.28948677
# ...save actor...
# episode  62 score 88.7 avg score 24 steps  102 alpha  0.285513
# episode  63 score 18.0 avg score 24 steps  38 alpha  0.281664
# episode  64 score 24.3 avg score 24 steps  31 alpha  0.27979523
# episode  65 score 26.3 avg score 24 steps  35 alpha  0.27793154
# episode  66 score 25.0 avg score 24 steps  33 alpha  0.27608648
# episode  67 score 26.3 avg score 24 steps  33 alpha  0.27428415
# episode  68 score 22.7 avg score 24 steps  30 alpha  0.27268097
# episode  69 score 25.0 avg score 24 steps  32 alpha  0.27105817
# episode  70 score 24.1 avg score 24 steps  36 alpha  0.26931512
# episode  71 score 25.0 avg score 24 steps  33 alpha  0.2675082
# episode  72 score 23.9 avg score 24 steps  35 alpha  0.26571295
# ...save actor...
# episode  73 score 26.4 avg score 24 steps  34 alpha  0.26391754
# ...save actor...
# episode  74 score 25.1 avg score 24 steps  50 alpha  0.2617543
# ...save actor...
# episode  75 score 83.8 avg score 25 steps  111 alpha  0.25756025
# ...save actor...
# episode  76 score 27.4 avg score 25 steps  42 alpha  0.25374314
# episode  77 score 24.7 avg score 25 steps  32 alpha  0.25184822
# ...save actor...
# episode  78 score 27.5 avg score 25 steps  46 alpha  0.24988969
# ...save actor...
# episode  79 score 99.5 avg score 26 steps  97 alpha  0.24632151
# ...save actor...
# episode  80 score 26.7 avg score 26 steps  32 alpha  0.24316144
# episode  81 score 25.1 avg score 26 steps  32 alpha  0.24164157
# episode  82 score 23.8 avg score 26 steps  32 alpha  0.24017438
# episode  83 score 23.2 avg score 26 steps  32 alpha  0.23869927
# ...save actor...
# episode  84 score 73.8 avg score 26 steps  85 alpha  0.23573011
# episode  85 score 25.5 avg score 26 steps  32 alpha  0.23291199
# episode  86 score 25.6 avg score 26 steps  46 alpha  0.23105918
# episode  87 score 26.0 avg score 26 steps  33 alpha  0.2292207
# ...save actor...
# episode  88 score 198.5 avg score 28 steps  226 alpha  0.22280718
# episode  89 score 23.5 avg score 28 steps  31 alpha  0.21660894
# ...save actor...
# episode  90 score 230.6 avg score 31 steps  211 alpha  0.21066816
# episode  91 score 28.4 avg score 31 steps  35 alpha  0.20485908
# episode  92 score 26.3 avg score 30 steps  34 alpha  0.2032903
# episode  93 score 27.1 avg score 30 steps  34 alpha  0.20172662
# ...save actor...
# episode  94 score 135.8 avg score 32 steps  156 alpha  0.19730118
# ...save actor...
# episode  95 score 224.9 avg score 34 steps  217 alpha  0.18892406
# ...save actor...
# episode  96 score 251.0 avg score 36 steps  254 alpha  0.17840387
# ...save actor...
# episode  97 score 63.9 avg score 36 steps  81 alpha  0.17130996
# ...save actor...
# episode  98 score 108.1 avg score 37 steps  133 alpha  0.1669142
# ...save actor...
# episode  99 score 120.0 avg score 38 steps  158 alpha  0.16084161
# ...save actor...
# episode  100 score 119.9 avg score 39 steps  132 alpha  0.1549441
# ...save actor...
# episode  101 score 111.5 avg score 40 steps  134 alpha  0.1498162
# ...save actor...
# episode  102 score 113.1 avg score 42 steps  129 alpha  0.14479496
# ...save actor...
# episode  103 score 33.2 avg score 43 steps  66 alpha  0.14120875
# ...save actor...
# episode  104 score 42.8 avg score 44 steps  74 alpha  0.13869283
# ...save actor...
# episode  105 score 41.7 avg score 45 steps  77 alpha  0.13611
# ...save actor...
# episode  106 score 49.1 avg score 46 steps  77 alpha  0.13373032
# ...save actor...
# episode  107 score 51.1 avg score 47 steps  77 alpha  0.13130552
# ...save actor...
# episode  108 score 115.6 avg score 48 steps  137 alpha  0.12818229
# ...save actor...
# episode  109 score 226.3 avg score 49 steps  249 alpha  0.12292798
# ...save actor...
# episode  110 score 218.5 avg score 51 steps  194 alpha  0.11748628
# ...save actor...
# episode  111 score 505.8 avg score 56 steps  473 alpha  0.1102751
# ...save actor...
# episode  112 score 84.0 avg score 57 steps  160 alpha  0.10456137
# ...save actor...
# episode  113 score 114.7 avg score 57 steps  119 alpha  0.10248701
# ...save actor...
# episode  114 score 386.5 avg score 61 steps  296 alpha  0.099745326
# ...save actor...
# episode  115 score 115.6 avg score 63 steps  88 alpha  0.097654335
# ...save actor...
# episode  116 score 360.5 avg score 66 steps  289 alpha  0.09586054
# ...save actor...
# episode  117 score 127.2 avg score 68 steps  134 alpha  0.09396796
# ...save actor...
# episode  118 score 61.2 avg score 68 steps  72 alpha  0.09307783
# ...save actor...
# episode  119 score 51.9 avg score 68 steps  72 alpha  0.092719406
# ...save actor...
# episode  120 score 51.6 avg score 68 steps  69 alpha  0.09242795
# ...save actor...
# episode  121 score 64.2 avg score 69 steps  88 alpha  0.09202915
# ...save actor...
# episode  122 score 130.3 avg score 70 steps  116 alpha  0.0915096
# ...save actor...
# episode  123 score 620.7 avg score 75 steps  533 alpha  0.090992466
# ...save actor...
# episode  124 score 124.7 avg score 77 steps  97 alpha  0.09070377
# ...save actor...
# episode  125 score 110.9 avg score 77 steps  97 alpha  0.09035356
# ...save actor...
# episode  126 score 593.9 avg score 82 steps  450 alpha  0.09007468
# ...save actor...
# episode  127 score 171.9 avg score 84 steps  183 alpha  0.089796305
# ...save actor...
# episode  128 score 285.5 avg score 86 steps  187 alpha  0.08942671
# ...save actor...
# episode  129 score 203.9 avg score 88 steps  199 alpha  0.08809246
# ...save actor...
# episode  130 score 196.1 avg score 89 steps  183 alpha  0.08714918
# ...save actor...
# episode  131 score 133.5 avg score 90 steps  145 alpha  0.08668734
# ...save actor...
# episode  132 score 192.8 avg score 92 steps  199 alpha  0.08709057
# ...save actor...
# episode  133 score 157.3 avg score 93 steps  134 alpha  0.08763629
# ...save actor...
# episode  134 score 179.3 avg score 94 steps  224 alpha  0.08797909
# ...save actor...
# episode  135 score 197.8 avg score 95 steps  185 alpha  0.08830772
# ...save actor...
# episode  136 score 200.2 avg score 97 steps  190 alpha  0.08888724
# ...save actor...
# episode  137 score 340.1 avg score 100 steps  356 alpha  0.08967822
# ...save actor...
# episode  138 score 268.7 avg score 103 steps  180 alpha  0.09098545
# ...save actor...
# episode  139 score 321.2 avg score 106 steps  251 alpha  0.092444494
# ...save actor...
# episode  140 score 179.3 avg score 107 steps  116 alpha  0.09315729
# ...save actor...
# episode  141 score 178.4 avg score 109 steps  135 alpha  0.09312929
# ...save actor...
# episode  142 score 231.7 avg score 111 steps  231 alpha  0.092986204
# ...save actor...
# episode  143 score 143.5 avg score 112 steps  117 alpha  0.09323808
# ...save actor...
# episode  144 score 280.8 avg score 115 steps  180 alpha  0.09274673
# ...save actor...
# episode  145 score 246.6 avg score 117 steps  205 alpha  0.09241415
# ...save actor...
# episode  146 score 271.7 avg score 119 steps  219 alpha  0.09164843
# ...save actor...
# episode  147 score 639.0 avg score 125 steps  600 alpha  0.09261117
# ...save actor...
# episode  148 score 592.9 avg score 131 steps  600 alpha  0.094536886
# ...save actor...
# episode  149 score 236.3 avg score 133 steps  188 alpha  0.096364126
# ...save actor...
# episode  150 score 575.8 avg score 138 steps  600 alpha  0.09779264
# ...save actor...
# episode  151 score 299.4 avg score 140 steps  228 alpha  0.099409565
# ...save actor...
# episode  152 score 199.0 avg score 142 steps  123 alpha  0.09961684
# ...save actor...
# episode  153 score 705.8 avg score 148 steps  600 alpha  0.10141418
# ...save actor...
# episode  154 score 400.2 avg score 152 steps  334 alpha  0.103823185
# ...save actor...
# episode  155 score 703.5 avg score 158 steps  600 alpha  0.10467681
# ...save actor...
# episode  156 score 597.6 avg score 164 steps  600 alpha  0.1061866
# ...save actor...
# episode  157 score 655.6 avg score 170 steps  600 alpha  0.10525502
# ...save actor...
# episode  158 score 178.6 avg score 172 steps  165 alpha  0.10493526
# ...save actor...
# episode  159 score 686.2 avg score 179 steps  597 alpha  0.104646474
# ...save actor...
# episode  160 score 321.6 avg score 182 steps  272 alpha  0.10555003
# ...save actor...
# episode  161 score 718.8 avg score 188 steps  600 alpha  0.10582006
# ...save actor...
# episode  162 score 559.1 avg score 193 steps  600 alpha  0.10700966
# ...save actor...
# episode  163 score 653.1 avg score 200 steps  600 alpha  0.107070565
# ...save actor...
# episode  164 score 655.7 avg score 206 steps  600 alpha  0.10783597
# ...save actor...
# episode  165 score 745.9 avg score 213 steps  600 alpha  0.10838606
# ...save actor...
# episode  166 score 701.3 avg score 220 steps  600 alpha  0.10903902
# ...save actor...
# episode  167 score 915.1 avg score 229 steps  600 alpha  0.110197246
# ...save actor...
# episode  168 score 662.6 avg score 235 steps  600 alpha  0.11028335
# ...save actor...
# episode  169 score 814.8 avg score 243 steps  600 alpha  0.11168953
# ...save actor...
# episode  170 score 782.7 avg score 251 steps  600 alpha  0.112807274
# ...save actor...
# episode  171 score 773.7 avg score 258 steps  600 alpha  0.113019496
# ...save actor...
# episode  172 score 715.1 avg score 265 steps  600 alpha  0.115032785
# ...save actor...
# episode  173 score 799.6 avg score 273 steps  600 alpha  0.115851656
# ...save actor...
# episode  174 score 641.4 avg score 279 steps  600 alpha  0.11591722
# ...save actor...
# episode  175 score 753.5 avg score 286 steps  600 alpha  0.11554464
# ...save actor...
# episode  176 score 703.9 avg score 292 steps  600 alpha  0.116539255
# ...save actor...
# episode  177 score 705.6 avg score 299 steps  600 alpha  0.119304225
# ...save actor...
# episode  178 score 796.8 avg score 307 steps  600 alpha  0.12038544
# ...save actor...
# episode  179 score 747.1 avg score 313 steps  600 alpha  0.118984185
# ...save actor...
# episode  180 score 924.2 avg score 322 steps  600 alpha  0.11676315
# ...save actor...
# episode  181 score 792.6 avg score 330 steps  600 alpha  0.117109336
# ...save actor...
# episode  182 score 798.6 avg score 338 steps  600 alpha  0.11804795
# ...save actor...
# episode  183 score 645.2 avg score 344 steps  600 alpha  0.118932344
# ...save actor...
# episode  184 score 906.9 avg score 352 steps  600 alpha  0.11900657
# ...save actor...
# episode  185 score 795.5 avg score 360 steps  600 alpha  0.11920402
# ...save actor...
# episode  186 score 952.2 avg score 369 steps  600 alpha  0.12059977
# ...save actor...
# episode  187 score 664.0 avg score 376 steps  600 alpha  0.11994481
# ...save actor...
# episode  188 score 691.5 avg score 381 steps  600 alpha  0.11983695
# ...save actor...
# episode  189 score 788.0 avg score 388 steps  600 alpha  0.121707715
# ...save actor...
# episode  190 score 764.7 avg score 394 steps  600 alpha  0.120513715
# ...save actor...
# episode  191 score 891.8 avg score 402 steps  600 alpha  0.11871975
# ...save actor...
# episode  192 score 827.2 avg score 410 steps  600 alpha  0.11998945
# ...save actor...
# episode  193 score 779.8 avg score 418 steps  600 alpha  0.12159428
# ...save actor...
# episode  194 score 890.3 avg score 425 steps  600 alpha  0.123941004
# ...save actor...
# episode  195 score 834.6 avg score 431 steps  600 alpha  0.12572671
# ...save actor...
# episode  196 score 828.8 avg score 437 steps  600 alpha  0.12511468
# ...save actor...
# episode  197 score 842.6 avg score 445 steps  600 alpha  0.12546931
# ...save actor...
# episode  198 score 682.3 avg score 451 steps  600 alpha  0.12584223
# ...save actor...
# episode  199 score 824.7 avg score 458 steps  600 alpha  0.12534945
# ...save actor...
# episode  200 score 752.3 avg score 464 steps  600 alpha  0.12519546
# ...save actor...
# episode  201 score 848.8 avg score 471 steps  600 alpha  0.12601155
# ...save actor...
# episode  202 score 924.0 avg score 480 steps  600 alpha  0.1277448
# ...save actor...
# episode  203 score 770.8 avg score 487 steps  600 alpha  0.12862739
# ...save actor...
# episode  204 score 849.8 avg score 495 steps  600 alpha  0.12801707
# ...save actor...
# episode  205 score 987.9 avg score 504 steps  600 alpha  0.12576099
# ...save actor...
# episode  206 score 774.7 avg score 512 steps  600 alpha  0.124595135
# ...save actor...
# episode  207 score 986.8 avg score 521 steps  600 alpha  0.12557673
# ...save actor...
# episode  208 score 917.2 avg score 529 steps  600 alpha  0.12657668
# ...save actor...
# episode  209 score 1015.0 avg score 537 steps  600 alpha  0.1254122
# ...save actor...
# episode  210 score 901.9 avg score 544 steps  600 alpha  0.12532993
# ...save actor...
# episode  211 score 859.6 avg score 547 steps  600 alpha  0.12636639
# ...save actor...
# episode  212 score 855.7 avg score 555 steps  600 alpha  0.12728263
# ...save actor...
# episode  213 score 925.4 avg score 563 steps  600 alpha  0.12713505
# ...save actor...
# episode  214 score 845.5 avg score 568 steps  600 alpha  0.12810278
# ...save actor...
# episode  215 score 893.0 avg score 575 steps  600 alpha  0.13072973
# ...save actor...
# episode  216 score 874.4 avg score 581 steps  600 alpha  0.13140696
# ...save actor...
# episode  217 score 368.0 avg score 583 steps  213 alpha  0.13229212
# ...save actor...
# episode  218 score 878.6 avg score 591 steps  600 alpha  0.13198715
# ...save actor...
# episode  219 score 315.3 avg score 594 steps  195 alpha  0.1304025
# ...save actor...
# episode  220 score 891.0 avg score 602 steps  600 alpha  0.12942494
# ...save actor...
# episode  221 score 1077.4 avg score 612 steps  600 alpha  0.12924701
# ...save actor...
# episode  222 score 938.0 avg score 620 steps  600 alpha  0.12809733
# ...save actor...
# episode  223 score 833.2 avg score 623 steps  600 alpha  0.12774454
# ...save actor...
# episode  224 score 717.5 avg score 628 steps  600 alpha  0.1295882
# ...save actor...
# episode  225 score 950.1 avg score 637 steps  600 alpha  0.12819366
# ...save actor...
# episode  226 score 1057.0 avg score 642 steps  600 alpha  0.12666203
# ...save actor...
# episode  227 score 977.0 avg score 650 steps  600 alpha  0.12563284
# ...save actor...
# episode  228 score 903.6 avg score 656 steps  600 alpha  0.1256231
# ...save actor...
# episode  229 score 814.8 avg score 662 steps  600 alpha  0.123172686
# ...save actor...
# episode  230 score 1040.9 avg score 670 steps  600 alpha  0.12282955
# ...save actor...
# episode  231 score 1140.5 avg score 680 steps  600 alpha  0.122229
# ...save actor...
# episode  232 score 1029.8 avg score 689 steps  600 alpha  0.12177093
# ...save actor...
# episode  233 score 1098.2 avg score 698 steps  600 alpha  0.123687364
# ...save actor...
# episode  234 score 994.7 avg score 706 steps  600 alpha  0.1230528
# ...save actor...
# episode  235 score 1042.8 avg score 715 steps  600 alpha  0.123696394
# ...save actor...
# episode  236 score 1134.8 avg score 724 steps  600 alpha  0.124019824
# ...save actor...
# episode  237 score 1120.2 avg score 732 steps  600 alpha  0.12355068
# ...save actor...
# episode  238 score 1022.3 avg score 739 steps  600 alpha  0.12332884
# ...save actor...
# episode  239 score 375.3 avg score 740 steps  186 alpha  0.123852946
# ...save actor...
# episode  240 score 1044.5 avg score 749 steps  600 alpha  0.122776896
# ...save actor...
# episode  241 score 1033.1 avg score 757 steps  600 alpha  0.12272073
# ...save actor...
# episode  242 score 1072.6 avg score 766 steps  600 alpha  0.12270158
# ...save actor...
# episode  243 score 1242.4 avg score 777 steps  600 alpha  0.12349462
# ...save actor...
# episode  244 score 1142.4 avg score 785 steps  600 alpha  0.12473035
# ...save actor...
# episode  245 score 1107.4 avg score 794 steps  568 alpha  0.12505223
# ...save actor...
# episode  246 score 961.9 avg score 801 steps  600 alpha  0.12571739
# episode  247 score 451.6 avg score 799 steps  231 alpha  0.12668759
# ...save actor...
# episode  248 score 992.8 avg score 803 steps  600 alpha  0.12535281
# ...save actor...
# episode  249 score 1231.6 avg score 813 steps  600 alpha  0.12517904
# ...save actor...
# episode  250 score 1208.4 avg score 819 steps  600 alpha  0.12516375
# ...save actor...
# episode  251 score 1294.1 avg score 829 steps  600 alpha  0.12683728
# ...save actor...
# episode  252 score 543.3 avg score 833 steps  325 alpha  0.12711103
# ...save actor...
# episode  253 score 1105.1 avg score 836 steps  600 alpha  0.12685762
# ...save actor...
# episode  254 score 658.3 avg score 839 steps  360 alpha  0.12696317
# ...save actor...
# episode  255 score 1252.9 avg score 845 steps  600 alpha  0.12675641
# ...save actor...
# episode  256 score 979.2 avg score 848 steps  600 alpha  0.12720576
# ...save actor...
# episode  257 score 982.7 avg score 852 steps  600 alpha  0.12579963
# ...save actor...
# episode  258 score 1188.0 avg score 862 steps  600 alpha  0.12513593
# ...save actor...
# episode  259 score 1188.5 avg score 867 steps  600 alpha  0.12515938
# ...save actor...
# episode  260 score 1219.1 avg score 876 steps  600 alpha  0.1254976
# ...save actor...
# episode  261 score 791.4 avg score 876 steps  600 alpha  0.12657274
# ...save actor...
# episode  262 score 1054.0 avg score 881 steps  600 alpha  0.12816086
# ...save actor...
# episode  263 score 1231.9 avg score 887 steps  600 alpha  0.12661445
# ...save actor...
# episode  264 score 1051.7 avg score 891 steps  600 alpha  0.12689911
# ...save actor...
# episode  265 score 1185.1 avg score 896 steps  600 alpha  0.12786146
# episode  266 score 389.2 avg score 892 steps  219 alpha  0.12700377
# episode  267 score 939.7 avg score 893 steps  600 alpha  0.12631473
# ...save actor...
# episode  268 score 1286.3 avg score 899 steps  600 alpha  0.12511823
# ...save actor...
# episode  269 score 1181.7 avg score 903 steps  600 alpha  0.12673777
# ...save actor...
# episode  270 score 1258.1 avg score 907 steps  600 alpha  0.12689535
# ...save actor...
# episode  271 score 1156.2 avg score 911 steps  600 alpha  0.12655158
# ...save actor...
# episode  272 score 1206.7 avg score 916 steps  600 alpha  0.1264667
# ...save actor...
# episode  273 score 1146.8 avg score 920 steps  600 alpha  0.12604979
# ...save actor...
# episode  274 score 1168.4 avg score 925 steps  600 alpha  0.1267155
# episode  275 score 400.4 avg score 921 steps  214 alpha  0.1260237
# ...save actor...
# episode  276 score 1080.3 avg score 925 steps  600 alpha  0.12586732
# ...save actor...
# episode  277 score 851.8 avg score 927 steps  419 alpha  0.12724371
# episode  278 score 346.5 avg score 922 steps  194 alpha  0.12834594
# episode  279 score 1128.9 avg score 926 steps  600 alpha  0.12764162
# ...save actor...
# episode  280 score 1261.0 avg score 929 steps  600 alpha  0.12914973
# episode  281 score 566.8 avg score 927 steps  296 alpha  0.12985149
# episode  282 score 750.6 avg score 926 steps  375 alpha  0.13008174
# ...save actor...
# episode  283 score 1195.6 avg score 932 steps  600 alpha  0.12982681
# ...save actor...
# episode  284 score 1165.5 avg score 935 steps  600 alpha  0.12764123
# ...save actor...
# episode  285 score 1172.0 avg score 938 steps  600 alpha  0.12719083
# ...save actor...
# episode  286 score 1270.0 avg score 942 steps  600 alpha  0.1293092
# ...save actor...
# episode  287 score 1159.7 avg score 946 steps  600 alpha  0.12937506
# ...save actor...
# episode  288 score 1216.2 avg score 952 steps  600 alpha  0.12817828
# ...save actor...
# episode  289 score 1069.6 avg score 955 steps  600 alpha  0.12953097
# ...save actor...
# episode  290 score 1257.7 avg score 959 steps  600 alpha  0.13014781
# ...save actor...
# episode  291 score 1227.3 avg score 963 steps  600 alpha  0.13245882
# ...save actor...
# episode  292 score 1264.1 avg score 967 steps  600 alpha  0.13227557
# ...save actor...
# episode  293 score 1172.3 avg score 971 steps  600 alpha  0.13224886
# ...save actor...
# episode  294 score 1198.8 avg score 974 steps  600 alpha  0.13173647
# ...save actor...
# episode  295 score 1127.9 avg score 977 steps  600 alpha  0.13261046
# ...save actor...
# episode  296 score 1254.3 avg score 981 steps  600 alpha  0.1314038
# ...save actor...
# episode  297 score 1288.3 avg score 986 steps  600 alpha  0.13033515
# ...save actor...
# episode  298 score 1245.6 avg score 991 steps  600 alpha  0.13028055
# ...save actor...
# episode  299 score 1261.4 avg score 996 steps  600 alpha  0.13221459
# ...save actor...
# episode  300 score 1057.0 avg score 999 steps  600 alpha  0.13131051
# ...save actor...
# episode  301 score 1298.5 avg score 1003 steps  600 alpha  0.1304246
# ...save actor...
# episode  302 score 1249.3 avg score 1007 steps  600 alpha  0.13025966
# ...save actor...
# episode  303 score 1269.6 avg score 1012 steps  600 alpha  0.13128777
# ...save actor...
# episode  304 score 1270.8 avg score 1016 steps  600 alpha  0.13282648
# ...save actor...
# episode  305 score 1247.7 avg score 1018 steps  600 alpha  0.13378003
# ...save actor...
# episode  306 score 1261.7 avg score 1023 steps  600 alpha  0.1335291
# ...save actor...
# episode  307 score 1292.6 avg score 1026 steps  600 alpha  0.13382214
# ...save actor...
# episode  308 score 1295.1 avg score 1030 steps  600 alpha  0.13257682
# episode  309 score 798.5 avg score 1028 steps  401 alpha  0.13206303
# ...save actor...
# episode  310 score 1192.6 avg score 1031 steps  600 alpha  0.13424423
# ...save actor...
# episode  311 score 1265.4 avg score 1035 steps  600 alpha  0.1344137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9a2caa707757> in <module>
#      25         observation_, reward, done = env.step(action)
#      26         agent.remember(observation, action, reward, observation_, done)
# ---> 27         agent.learn()
#      28         observation = observation_
#      29         score += reward
#
# <ipython-input-6-fe1c92459723> in learn(self)
#     183         ## Update critic networks Q1 & Q2
#     184         with tf.GradientTape(persistent=True) as tape_Q:
# --> 185             next_actions, next_log_pi, _ = self.policy_net(next_states)
#     186             Q1_next = self.target_q_net1(next_states, next_actions)
#     187             Q2_next = self.target_q_net2(next_states, next_actions)
#
# ~\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-5-8fc52e3b130b> in call(self, state)
#      58     def call(self, state):
#      59         x = self.fc1(state)
# ---> 60         x = self.fc2(x)
#      61         mu = self.mu(x)
#      62
#
# ~\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\keras\layers\core.py in call(self, inputs)
#    1142         outputs = gen_math_ops.mat_mul(inputs, self.kernel)
#    1143     if self.use_bias:
# -> 1144       outputs = nn.bias_add(outputs, self.bias)
#    1145     if self.activation is not None:
#    1146       return self.activation(outputs)  # pylint: disable=not-callable
#
# ~\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\ops\nn_ops.py in bias_add(value, bias, data_format, name)
#    2756     else:
#    2757       return gen_nn_ops.bias_add(
# -> 2758           value, bias, data_format=data_format, name=name)
#    2759
#    2760
#
# ~\anaconda3\envs\master\lib\site-packages\tensorflow_core\python\ops\gen_nn_ops.py in bias_add(value, bias, data_format, name)
#     669       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#     670         _ctx._context_handle, tld.device_name, "BiasAdd", name,
# --> 671         tld.op_callbacks, value, bias, "data_format", data_format)
#     672       return _result
#     673     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
plot_learning_curve(score_history, figure_file_return+'.png', color='lightgreen', avg_color='green', Ylabel='Return')
plot_learning_curve(alpha_history, figure_file_alpha+'.png', color='blue', Ylabel='Temperature alpha')

np.save(figure_file_return, score_history)

# %%
x = []
theta1 = []
theta2 = []
dx = []
dtheta1 = []
dtheta2 = []
force = []

for i in range(1):
    observation = env.reset()
    done = False
    while not done:
        x.append(observation[0])
        theta1.append(observation[1])
        theta2.append(observation[2])
        dx.append(observation[3])
        dtheta1.append(observation[4])
        dtheta2.append(observation[5])
        action = agent.choose_action(observation)
        force.append(action)
        observation_, _, done = env.step(action)
        observation = observation_
    
n_steps = len(x)
t = [env.dt*i for i in range(n_steps)]

plt.plot(t, np.rad2deg(theta1), label='phi1', color='green')
plt.title('pendulum 1 angle')
plt.ylabel('phi1 [deg]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'phi_1.png')
plt.show()

plt.plot(t, np.rad2deg(theta2), label='phi1', color='red')
plt.title('pendulum 2 angle')
plt.ylabel('phi2 [deg]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'phi_2.png')
plt.show()


plt.plot(t, x, label='x')
plt.title('cart position')
plt.ylabel('x [m]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'cart_distance.png')
plt.show()


plt.plot(t, dx, label='dx')
plt.plot(t, dtheta1, label='dphi1')
plt.plot(t, dtheta2, label='dphi2')
plt.title('velocities')
plt.ylabel('dx [m/s]   dphi1, dphi2 [rad/s]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'velocities.png')
plt.show()


plt.plot(t, force)
plt.title('horizontal force on cart')
plt.ylabel('F [N]')
plt.xlabel('time [s]')
plt.savefig('plots/' + 'control_variable.png')
plt.show()


l1, l2 = 0.35, 0.48

x_u = [x[i] + l1*sin(theta1[i]) for i in range(len(x))]
y_u = [l1*cos(theta1[i]) for i in range(len(x))]

x_o = [x[i] + l1*sin(theta1[i]) + l2*sin(theta2[i]) for i in range(len(x))]
y_o = [l1*cos(theta1[i]) + l2*cos(theta2[i]) for i in range(len(x))]

plt.plot(x_u, y_u)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()

plt.plot(x_o, y_o)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()

plt.plot(x_u, y_u)
plt.plot(x_o, y_o)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()

# %%
#env = CartPoleBalance(max_force=40.0, max_timesteps=1000)  ## 200 funktioniert gut!
for i in range(10):
    observation = env.reset()
    done = False
    while not done:
        env.render()
        action = agent.choose_action(observation)
        #action = np.array([0.0])
        observation_, _, done = env.step(action)
        observation = observation_
env.close()

# %%
def wrap2pi(x):
    return (((x+np.pi) % (2*np.pi)) - np.pi)

# %%
a = angle_normalize(np.deg2rad(-181))
print(np.rad2deg(a))

# %%
True or False

# %%
env.close()
