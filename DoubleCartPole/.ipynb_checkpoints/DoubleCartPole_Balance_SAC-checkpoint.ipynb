# %% [markdown]
# # Stabilize Inverted Cartpole with Deep Reinforcement Learning

# %% [markdown]
# In this notebook the environment of a double inverted cartpole is implemented.
# The pendulum starts in a state very close to the unstable equilibrium $\theta_1, \theta_2 \approx 0$.
# The goal is to create a reinforcement learning agent which will stabilize the cartpole in this inverted position. The trained neural network of the agent will observe the state $s_t$ of the physical system and will output the horizontal Force $f_t$ acting on the cart to control the double cartpole system.
# No classical control theory will be used to achieve this.

# %% [markdown]
# # 1. Double Cartpole Environment

# %% [markdown]
# ![Double-inverted-pendulum-on-a-cart.png](attachment:Double-inverted-pendulum-on-a-cart.png)

# %% [markdown]
# Quelle: Alexander Bogdanov - Optimal Control of a Double Inverted Pendulum on a Cart
#
# https://www.researchgate.net/figure/Double-inverted-pendulum-on-a-cart_fig1_250107215

# %%
import numpy as np
from math import sin, cos
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
class CartPoleBalance:
    def __init__(self, max_force, max_phi, max_timesteps):
        self.state = None
        self.max_speed = 12.0 # [m/s], [rad/s]
        self.max_x = 3.0
        self.max_phi = max_phi
        self.max_force = max_force # [N]
        self.max_timesteps = max_timesteps
        
        self.action_space_low = np.array([-self.max_force])
        self.action_space_high = np.array([self.max_force])
        
        self.observation_space_high = np.array([self.max_x, self.max_phi, self.max_phi, self.max_speed, self.max_speed, self.max_speed])
        self.observation_space_low = - np.array([self.max_x, self.max_phi, self.max_phi, self.max_speed, self.max_speed, self.max_speed])
        
        self.dt = 0.02
        self.steps = 0
        
        self.viewer = None
        self.state=None
    
    def step(self, action):
        self.steps += 1
        q, theta1, theta2, dq, dtheta1, dtheta2 = self.state
        
        # force is bounded due to maximum motor torque of actuator
        F = np.clip(action, -self.max_force, self.max_force)[0]
        
        x0 = [q, theta1, theta2, dq, dtheta1, dtheta2]
        integration_timesteps = np.linspace(0, self.dt, 8)
        X = odeint(self.cartpole_dXdt, x0, integration_timesteps, args=(F,))
        
        # pick last elements of trajectory
        q = X[-1, 0]  
        theta1 = X[-1, 1]
        theta2 = X[-1, 2]
        dq = X[-1, 3]
        dtheta1 = X[-1, 4]
        dtheta2 = X[-1, 5]
        
        self.state = np.array([q, theta1, theta2, dq, dtheta1, dtheta2])
        
        # epsidoe ends when done = True
        done = bool(
            q < -self.max_x
            or q > self.max_x
            or theta1 < -self.max_phi
            or theta1 > self.max_phi
            or theta2 < -self.max_phi
            or theta2 > self.max_phi
            or self.steps >= self.max_timesteps)
        
        # reward function of transition s_t, action --> s_t+1
        #reward = 1.0 if not done else 0.0 # funktioniert
        if not done:
            reward = 1.0 - (q/self.max_x)**2
        elif done and self.steps >= self.max_timesteps:
            reward = 100.0
        elif done and self.steps < self.max_timesteps:
            reward = -100
        #reward = 1.0 - 0.5*dx**2 if not done else -10.0 # funktioniert gut
        #reward = 1.0 - 1.0*dx**2 - 1.2*x**2 - 10.0*phi**2 if not done else -20
        #if self.steps >= self.max_timesteps:
        #    reward = reward + 80
            
        # Swing up: https://ww2.mathworks.cn/help/reinforcement-learning/ug/train-ddpg-agent-to-swing-up-and-balance-cart-pole-system.html
        
        return self.state, reward, done
        
    
    def cartpole_dXdt(self, X, t, u):
        m, m1, m2 = 0.6, 0.853, 0.51
        g = 9.81
        d1, d2, d3 = 0.003, 0.003, 0.003
        l1, l2 = 0.35, 0.48
        
        q, theta1, theta2, dq, dtheta1, dtheta2 = X
    
        ddq = ((2*l1*l2*m1*u + l1*l2*m2*u - d2*dtheta1*l2*m2*cos(theta1 - 2*theta2) + 2*dtheta1**2*l1**2*l2*m1**2*sin(theta1) 
            -d3*dtheta2*l1*m1*cos(2*theta1 - theta2) - d3*dtheta2*l1*m2*cos(2*theta1 - theta2) - 2*d1*dq*l1*l2*m1 
            -d1*dq*l1*l2*m2 - l1*l2*m2*u*cos(2*theta1 - 2*theta2) - g*l1*l2*m1**2*sin(2*theta1) 
            +2*d2*dtheta1*l2*m1*cos(theta1) + d2*dtheta1*l2*m2*cos(theta1) + d3*dtheta2*l1*m1*cos(theta2) 
            +d3*dtheta2*l1*m2*cos(theta2) + 2*dtheta1**2*l1**2*l2*m1*m2*sin(theta1) + dtheta2**2*l1*l2**2*m1*m2*sin(theta2)
            +dtheta2**2*l1*l2**2*m1*m2*sin(2*theta1 - theta2) - g*l1*l2*m1*m2*sin(2*theta1) 
            + d1*dq*l1*l2*m2*cos(2*theta1 - 2*theta2))/(l1*l2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + m1**2 
                                                               - m1*m2*cos(2*theta1) - m*m2*cos(2*theta1 - 2*theta2))))
    
        ddtheta1 =  (-(2*d2*dtheta1*l2*m + 2*d2*dtheta1*l2*m1 + d2*dtheta1*l2*m2 - 2*d3*dtheta2*l1*m*cos(theta1 - theta2) -
                   d3*dtheta2*l1*m1*cos(theta1 - theta2) - d3*dtheta2*l1*m2*cos(theta1 - theta2) - 
                   l1*l2*m2*u*cos(theta1 -2*theta2) - d2*dtheta1*l2*m2*cos(2*theta2) - 2*g*l1*l2*m1**2*sin(theta1) 
                   + dtheta1**2*l1**2*l2*m1**2*sin(2*theta1) + d3*dtheta2*l1*m1*cos(theta1 + theta2) + 
                   d3*dtheta2*l1*m2*cos(theta1 + theta2) + 2*l1*l2*m1*u*cos(theta1) + l1*l2*m2*u*cos(theta1) - 
                   2*d1*dq*l1*l2*m1*cos(theta1) - d1*dq*l1*l2*m2*cos(theta1) + 
                   2*dtheta2**2*l1*l2**2*m*m2*sin(theta1 - theta2) + dtheta2**2*l1*l2**2*m1*m2*sin(theta1 - theta2) - 
                   2*g*l1*l2*m*m1*sin(theta1) - g*l1*l2*m*m2*sin(theta1) - 2*g*l1*l2*m1*m2*sin(theta1) + 
                   d1*dq*l1*l2*m2*cos(theta1 - 2*theta2) + dtheta1**2*l1**2*l2*m1*m2*sin(2*theta1) - 
                   g*l1*l2*m*m2*sin(theta1 - 2*theta2) + dtheta1**2*l1**2*l2*m*m2*sin(2*theta1 - 2*theta2) + 
                   dtheta2**2*l1*l2**2*m1*m2*sin(theta1 + theta2))/(l1**2*l2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + 
                                                            m1**2 - m1*m2*cos(2*theta1) - m*m2*cos(2*theta1 - 2*theta2))))
    
        ddtheta2 =((d2*dtheta1*l2*m2**2*cos(theta1 - theta2) - d3*dtheta2*l1*m2**2 - d2*dtheta1*l2*m2**2*cos(theta1 + theta2) -
                l1*l2*m2**2*u*cos(theta2) - d3*dtheta2*l1*m1**2 - 2*d3*dtheta2*l1*m*m1 - 2*d3*dtheta2*l1*m*m2 -
                2*d3*dtheta2*l1*m1*m2 + d3*dtheta2*l1*m1**2*cos(2*theta1) + d3*dtheta2*l1*m2**2*cos(2*theta1) +
                l1*l2*m2**2*u*cos(2*theta1 - theta2) + dtheta2**2*l1*l2**2*m*m2**2*sin(2*theta1 - 2*theta2) -
                d2*dtheta1*l2*m1*m2*cos(theta1 + theta2) - d1*dq*l1*l2*m2**2*cos(2*theta1 - theta2) -
                g*l1*l2*m*m2**2*sin(2*theta1 - theta2) - l1*l2*m1*m2*u*cos(theta2) + 2*d2*dtheta1*l2*m*m2*cos(theta1 - theta2)
                + d2*dtheta1*l2*m1*m2*cos(theta1 - theta2) + d1*dq*l1*l2*m2**2*cos(theta2) + 2*d3*dtheta2*l1*m1*m2*cos(2*theta1)
                + 2*dtheta1**2*l1**2*l2*m*m2**2*sin(theta1 - theta2) + g*l1*l2*m*m2**2*sin(theta2) +
                l1*l2*m1*m2*u*cos(2*theta1 - theta2) - d1*dq*l1*l2*m1*m2*cos(2*theta1 - theta2) -
                g*l1*l2*m*m1*m2*sin(2*theta1 - theta2) + d1*dq*l1*l2*m1*m2*cos(theta2)
                +2*dtheta1**2*l1**2*l2*m*m1*m2*sin(theta1 - theta2) + g*l1*l2*m*m1*m2*sin(theta2))
               /(l1*l2**2*m2*(2*m*m1 + m*m2 + m1*m2 - m1**2*cos(2*theta1) + m1**2 - m1*m2*cos(2*theta1)
                              - m*m2*cos(2*theta1 - 2*theta2))))
        
        return float(dq), float(dtheta1), float(dtheta2), float(ddq), float(ddtheta1), float(ddtheta2)
    
    def reset(self):
        start_deg = 5
        self.steps = 0
        high = np.array([0.1, np.deg2rad(start_deg), np.deg2rad(start_deg), 0.001, 0.001, 0.001]) # q, theta1, theta2, dq, dtheta1, dtheta2
        self.state = np.random.uniform(low=-high, high=high)
        #self.state = np.array([0.0, np.deg2rad(90), np.deg2rad(90), 0.0, 0.0, 0.0]) ##########################
        return self.state
    
    def render(self, mode='human'):
        screen_width = 600
        screen_height = 600

        world_width = self.max_x * 2
        scale = screen_width/world_width
        carty = 100  # TOP OF CART
        polewidth = 10.0
        polelen = scale * (2 * 0.42)
        cartwidth = 50.0
        cartheight = 30.0

        if self.viewer is None:
            from gym.envs.classic_control import rendering
            self.viewer = rendering.Viewer(screen_width, screen_height)
            
            
            l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
            axleoffset = cartheight / 4.0
            cart = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            self.carttrans = rendering.Transform()
            cart.add_attr(self.carttrans)
            self.viewer.add_geom(cart)
            
            l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
            pole = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole.set_color(.8, .6, .4)
            self.poletrans = rendering.Transform(translation=(0, axleoffset))
            pole.add_attr(self.poletrans)
            pole.add_attr(self.carttrans)
            self.viewer.add_geom(pole)
            
            l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
            pole2 = rendering.FilledPolygon([(l, b), (l, t), (r, t), (r, b)])
            pole2.set_color(.2, .6, .4)
            self.poletrans2 = rendering.Transform(translation=(0, polelen))
            pole2.add_attr(self.poletrans2)
            pole2.add_attr(self.poletrans)
            pole2.add_attr(self.carttrans)
            self.viewer.add_geom(pole2)
            
            
            self.axle = rendering.make_circle(polewidth/2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(.5, .5, .8)
            self.viewer.add_geom(self.axle)
            
            self.axle = rendering.make_circle(polewidth/2)
            self.axle.add_attr(self.poletrans2)
            self.axle.add_attr(self.poletrans)
            self.axle.add_attr(self.carttrans)
            self.axle.set_color(.5, .5, .8)
            self.viewer.add_geom(self.axle)
            
            
            self.track = rendering.Line((0, 3*carty), (screen_width, 3*carty))  #4*
            self.track.set_color(0, 0, 0)
            self.viewer.add_geom(self.track)

            self._pole_geom = pole
            self._pole_geom2 = pole2

        if self.state is None:
            return None

        # Edit the pole polygon vertex
        pole = self._pole_geom
        l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
        pole.v = [(l, b), (l, t), (r, t), (r, b)]
        
        pole2 = self._pole_geom2
        l, r, t, b = -polewidth / 2, polewidth / 2, polelen - polewidth / 2, -polewidth / 2
        pole2.v = [(l, b), (l, t), (r, t), (r, b)]

        x = self.state
        cartx = x[0] * scale + screen_width / 2.0  # MIDDLE OF CART
        self.carttrans.set_translation(cartx, 3*carty)
        self.poletrans.set_rotation(-x[1])
        self.poletrans2.set_rotation(-x[2]+x[1])

        return self.viewer.render(return_rgb_array=mode == 'rgb_array')

    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %% [markdown]
# # 2. Deep Reinforcement Learning Agent - Soft Actor-Critic (SAC)
#
# Implementation of newest style of SAC with two Q Networks and temperature parameter alpha optimization/tuning.

# %%
import numpy as np
import os
import tensorflow as tf
import tensorflow_probability as tfp  # Distributions with reparam trick to gradients flow through
from tensorflow.keras.layers import Dense
from tensorflow.keras import initializers  # for layer weight initializing
import tensorflow.keras.losses as losses
#import gym
import matplotlib.pyplot as plt

# %% [markdown]
# ## Replay Buffer Class
# We implement a Replay Buffer to collect and sample the experiences, that the agent receives while acting in the environment according to the SAC algorithm.

# %%
class ReplayBuffer:
    def __init__(self, n_actions, input_shape, max_size=1000000):
        self.mem_size = max_size

        self.state_memory = np.zeros((self.mem_size, input_shape))
        self.new_state_memory = np.zeros((self.mem_size, input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

        self.n_count = 0

    def store_transition(self, state, action, reward, state_, done):
        index = self.n_count % self.mem_size

        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done

        self.n_count += 1

    def sample_buffer(self, batch_size=256):
        max_mem = min(self.n_count, self.mem_size)
        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones

# %% [markdown]
# ## Actor-Critic Neural Networks

# %%
class CriticNetwork(tf.keras.Model):
    def __init__(self, n_states, n_actions, fc1_dims, fc2_dims, network_name, chkpt_dir='tmp/SAC', init_w=3e-3):
        super(CriticNetwork, self).__init__()

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')

        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states + n_actions, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        self.q = Dense(units=1,
                       kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w), # Änderung
                       bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))

    def call(self, state, action):
        inputs = tf.concat([state, action], axis=1)
        x = self.fc1(inputs)
        x = self.fc2(x)
        return self.q(x) 


class ActorNetwork(tf.keras.Model):
    def __init__(self,
                 n_states,
                 n_actions,
                 fc1_dims,
                 fc2_dims,
                 network_name,
                 chkpt_dir='tmp/SAC',
                 init_w=3e-3,
                 log_std_min=-20,
                 log_std_max=2):
        super(ActorNetwork, self).__init__()
        
        self.log_std_min = log_std_min
        self.log_std_max = log_std_max

        self.network_name = network_name
        self.checkpoint_dir = chkpt_dir
        if not os.path.exists(self.checkpoint_dir):
            os.makedirs(self.checkpoint_dir)
        self.checkpoint_file = os.path.join(self.checkpoint_dir, network_name + '_SAC')
        
        self.fc1 = Dense(units=fc1_dims, activation='relu', input_shape=(n_states, ))
        self.fc2 = Dense(units=fc2_dims, activation='relu')
        
        self.mu = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        
        self.log_std = Dense(units=n_actions,
                      kernel_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w),
                      bias_initializer=initializers.RandomUniform(minval=-init_w, maxval=init_w))
        

    def call(self, state):
        x = self.fc1(state)
        x = self.fc2(x)
        mu = self.mu(x)
        
        log_std = self.log_std(x)
        log_std = tf.clip_by_value(log_std, clip_value_min=self.log_std_min, clip_value_max=self.log_std_max)
        std = tf.exp(log_std)
        
        normal = tfp.distributions.Normal(mu, std)  # make Gaussian distribution of mu, and sigma for actions
        
        z = normal.sample()  # sample from distribution with reparam trick
        action = tf.tanh(z)  # bound actions to [-1, +1]
        
        # correct log_probs because of bounding the actions
        log_prob = normal.log_prob(z) - tf.math.log(1 - tf.math.square(action) + 1e-6)  # Ist dasselbe!
        log_prob = tf.reduce_sum(log_prob, axis=1, keepdims=True) # tf.reduce_sum() or tf.reduce_mean()

        return action, log_prob, mu

# %% [markdown]
# ## Agent Class (Implementing SAC Algorithm)

# %%
class Agent:
    """ 2019 State-of-the-Art Implementation of SAC with optimized temperature

    """
    def __init__(self,
                 env,
                 lr_Q = 3e-4,
                 lr_actor = 3e-4,
                 lr_a = 3e-4,
                 gamma=0.99,
                 tau=0.005,
                 layer1_size=256,
                 layer2_size=256,
                 batch_size=256,
                 max_size=1000000,
                 warmup=1000,
                 policy_delay=1,
                 minimum_entropy=None):

        self.env = env
        self.action_range = [env.action_space_low, env.action_space_high]

        self.n_states = env.observation_space_low.shape[0]
        self.n_actions = env.action_space_low.shape[0]

        self.min_action = env.action_space_low
        self.max_action = env.action_space_high

        self.gamma = gamma
        self.tau = tau
        self.batch_size = batch_size
        self.warmup = warmup
        self.time_step = 0
        self.update_step = 0
        self.policy_delay = policy_delay

        self.policy_net = ActorNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                       fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Actor')

        self.q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_1')

        self.q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                    fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Critic_2')

        self.target_q_net1 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_1')

        self.target_q_net2 = CriticNetwork(n_states=self.n_states, n_actions=self.n_actions,
                                           fc1_dims=layer1_size, fc2_dims=layer2_size, network_name='Target_Critic_2')

        self.replay_buffer = ReplayBuffer(n_actions=self.n_actions,
                                          input_shape=self.n_states,
                                          max_size=max_size)
        
        self.policy_net.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_actor))
        self.q_net1.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))
        self.q_net2.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_Q))

        self.update_target_network_parameters(tau=1)  # copy parameters to target networks

        # entropy temperature parameter alpha
        #self.log_alpha = tf.Variable(0.0, dtype=tf.float32)
        print(-tf.constant(env.action_space_low.shape[0], dtype=tf.float32))
        
        self.log_alpha = tf.Variable(tf.zeros(1), trainable=True)
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32))
        self.minimum_entropy = -tf.reduce_prod(tf.convert_to_tensor(env.action_space_low.shape, dtype=tf.float32)) if minimum_entropy is None else minimum_entropy
        print('Minimum Entropy set to: ', self.minimum_entropy)
        self.alpha_optimizer = tf.keras.optimizers.Adam(learning_rate=lr_a)
        self.alpha = tf.exp(self.log_alpha).numpy()
        print('alpha: ', self.alpha)
        

    def choose_action(self, state):
        if self.time_step < self.warmup:
            actions = np.random.uniform(low=-1.0, high=1.0, size=self.n_actions)  # "random uniform distribution over all valid actions"
            actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        else:
            state = tf.convert_to_tensor(state, dtype=tf.float32)
            state = tf.expand_dims(state, axis=0)
            actions, _, _ = self.policy_net(state)

        self.time_step += 1
        if self.time_step == self.warmup:
            print('No warmup anymore!')
        a = self.rescale_action(actions[0].numpy())
        return a
    
    def control(self, state):
        state = tf.convert_to_tensor(state, dtype=tf.float32)
        state = tf.expand_dims(state, axis=0)
        _, _, mu = self.policy_net(state)
        return self.rescale_action(mu[0].numpy())

    def scale_action(self, action):
        """ Scale all actions to [-1., +1.]

        :param action: unscaled actions
        :return: scaled actions all in range -1. .. +1.
        """
        #old = 2 * (action - self.min_action) / (self.max_action - self.min_action) - 1.0
        scale = (2 * action - (self.action_range[1] + self.action_range[0])) / (self.action_range[1] - self.action_range[0])
        return scale

    def rescale_action(self, action):
        """ Rescale all scaled actions to environment actionspace values

        :param action: scaled actions
        :return: rescaled actions all in range min_action .. max_action
        """
        #old = (action + 1.0) * (self.max_action - self.min_action) / 2.0 + self.min_action
        rescale = action * (self.action_range[1] - self.action_range[0]) / 2.0 + \
               (self.action_range[1] + self.action_range[0]) / 2.0
        return rescale

    def remember(self, state, action, reward, new_state, done):
        action = self.scale_action(action)  # ÄNDERUNG! Funktioniert das mit?
        self.replay_buffer.store_transition(state, action, reward, new_state, done)

    def update_target_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau
        
        weights = []
        for theta_target, theta in zip(self.target_q_net1.get_weights(), 
                                       self.q_net1.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net1.set_weights(weights)
        
        weights = []
        for theta_target, theta in zip(self.target_q_net2.get_weights(),
                                       self.q_net2.get_weights()):
            theta_target = tau*theta + (1-tau)*theta_target
            weights.append(theta_target)
        self.target_q_net2.set_weights(weights)
        
        #weights = []
        #theta_target = self.target_q_net1.weights
        #for i, theta in enumerate(self.q_net1.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net1.set_weights(weights)
        # 
        #weights = []
        #theta_target = self.target_q_net2.weights
        #for i, theta in enumerate(self.q_net2.weights):
        #    weights.append(tau*theta + (1-tau)*theta_target[i])
        #self.target_q_net2.set_weights(weights)
        

    def save_models(self):
        #print('...save actor...')
        self.policy_net.save_weights('./Actor')

    def load_models(self):
        self.policy_net.load_weights('./Actor')

    def learn(self):
        if self.replay_buffer.n_count < self.batch_size:
            return
        elif self.replay_buffer.n_count == self.batch_size:
            print('Buffer Size equals batch Size! - Learning begins :)')
            return
        
        # sample batch from replay buffer
        states, actions, rewards, next_states, dones = self.replay_buffer.sample_buffer(batch_size=self.batch_size)
        
        # convert batchs from 2D numpy arrays to tensorflow tensors
        states = tf.convert_to_tensor(states, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        next_states = tf.convert_to_tensor(next_states, dtype=tf.float32)
        
        # expand rewards and dones from 1D numpy arrays to 2D tensors and reshape them
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        rewards = tf.expand_dims(rewards, axis=0)
        rewards = tf.reshape(rewards, [self.batch_size, 1])
        dones = tf.convert_to_tensor(dones, dtype=tf.float32)
        dones = tf.expand_dims(dones, axis=0)
        dones = tf.reshape(dones, [self.batch_size, 1])
        
        
        ## Update critic networks Q1 & Q2
        with tf.GradientTape(persistent=True) as tape_Q:
            next_actions, next_log_pi, _ = self.policy_net(next_states)
            Q1_next = self.target_q_net1(next_states, next_actions)
            Q2_next = self.target_q_net2(next_states, next_actions)
            next_q_target = tf.minimum(Q1_next, Q2_next) - self.alpha * next_log_pi
            expected_q = tf.stop_gradient(rewards + (1 - dones) * self.gamma * next_q_target)
            
            curr_q1 = self.q_net1(states, actions)
            curr_q2 = self.q_net2(states, actions)
            
            q1_loss = tf.reduce_mean((curr_q1 - expected_q)**2)
            q2_loss = tf.reduce_mean((curr_q2 - expected_q)**2)  # tf.square()
            q_loss = q1_loss + q2_loss
        
        grad_Q1 = tape_Q.gradient(q_loss, self.q_net1.trainable_variables)
        grad_Q2 = tape_Q.gradient(q_loss, self.q_net2.trainable_variables)
        
        self.q_net1.optimizer.apply_gradients(zip(grad_Q1, self.q_net1.trainable_variables))
        self.q_net2.optimizer.apply_gradients(zip(grad_Q2, self.q_net2.trainable_variables))
        

        ## Update policy network and polyak update target Q networks less frequently (like in TD3 --> Delayed SAC)
        if self.update_step % self.policy_delay == 0:
            with tf.GradientTape() as tape_policy:
                new_actions, log_pi, _ = self.policy_net(states)
                Q1 = self.q_net1(states, new_actions)
                Q2 = self.q_net2(states, new_actions)
                Q_min = tf.minimum(Q1, Q2)
                loss_policy = tf.reduce_mean(self.alpha * log_pi - Q_min)
            
            grad_policy = tape_policy.gradient(loss_policy, self.policy_net.trainable_variables)
            self.policy_net.optimizer.apply_gradients(zip(grad_policy, self.policy_net.trainable_variables))

            
            self.update_target_network_parameters()  # update target networks

        ## Update temperature
        with tf.GradientTape() as tape:
            _, log_pi_a, _ = self.policy_net(states)
            alpha_loss = tf.reduce_mean(self.log_alpha*(-log_pi_a - self.minimum_entropy))
            
        grads = tape.gradient(alpha_loss, [self.log_alpha])
        self.alpha_optimizer.apply_gradients(zip(grads, [self.log_alpha]))
        self.alpha = tf.exp(self.log_alpha).numpy()

        self.update_step += 1  # Keep track of the number of network updates

# %%
def plot_learning_curve(scores, figure_file, Ylabel, color, avg_color=None , plot_folder='./plots', Xlabel='Episodes'):
    if not os.path.exists(plot_folder):
        os.makedirs(plot_folder)
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i - 100):i + 1])

    plt.figure()
    plt.plot(scores, color=color)
    if avg_color is not None:
        plt.plot(running_avg, color=avg_color)
    plt.xlabel(Xlabel)
    plt.ylabel(Ylabel)
    plt.savefig(figure_file)

# %% [markdown]
# ## Main Loop

# %%
n_games = 700

env = CartPoleBalance(max_force=50.0, max_phi=np.deg2rad(18), max_timesteps=500)  ## 200 funktioniert gut!

agent = Agent(env=env)

filename_return = '_SAC_' + 'return_' 
filename_alpha = '_SAC_' + 'alpha_' 
figure_file_return = 'plots/' + filename_return
figure_file_alpha = 'plots/' + filename_alpha

best_score = -100000.0
score_history = []
alpha_history = []

for i in range(n_games):
    score = 0.0
    steps = 0
    alpha = []
    done = False
    observation = env.reset()
    while not done:
        steps += 1
        action = agent.choose_action(observation)
        observation_, reward, done = env.step(action)
        agent.remember(observation, action, reward, observation_, done)
        agent.learn()
        observation = observation_
        score += reward
        alpha.append(agent.alpha)

    score_history.append(score)
    alpha_history.append(np.mean(alpha))
    avg_score = np.mean(score_history[-100:])
    if avg_score > best_score:
        best_score = avg_score
        agent.save_models()
    if i % 25 == 0:
        print('episode ', i, 'score %.1f' % score, 'avg score %1.f' % avg_score, 'steps ', steps, 'alpha ', np.mean(alpha))
    
plot_learning_curve(score_history, figure_file_return+'.png', color='lightgreen', avg_color='green', Ylabel='Return')
plot_learning_curve(alpha_history, figure_file_alpha+'.png', color='blue', Ylabel='Temperature alpha')

np.save(figure_file_return, score_history)
# Out:
# tf.Tensor(-1.0, shape=(), dtype=float32)
# Minimum Entropy set to:  tf.Tensor(-1.0, shape=(), dtype=float32)
# alpha:  [1.]
# ...save actor...
# episode  0 score -81.0 avg score -81 steps  20 alpha  1.0
# episode  1 score -86.0 avg score -84 steps  15 alpha  1.0
# episode  2 score -95.0 avg score -87 steps  6 alpha  1.0
# episode  3 score -97.0 avg score -90 steps  4 alpha  1.0
# episode  4 score -89.0 avg score -90 steps  12 alpha  1.0
# episode  5 score -87.0 avg score -89 steps  14 alpha  1.0
# episode  6 score -93.0 avg score -90 steps  8 alpha  1.0
# episode  7 score -95.0 avg score -90 steps  6 alpha  1.0
# episode  8 score -94.0 avg score -91 steps  7 alpha  1.0
# episode  9 score -89.0 avg score -91 steps  12 alpha  1.0
# episode  10 score -96.0 avg score -91 steps  5 alpha  1.0
# episode  11 score -97.0 avg score -92 steps  4 alpha  1.0
# episode  12 score -97.0 avg score -92 steps  4 alpha  1.0
# episode  13 score -98.0 avg score -92 steps  3 alpha  1.0
# episode  14 score -97.0 avg score -93 steps  4 alpha  1.0
# episode  15 score -96.0 avg score -93 steps  5 alpha  1.0
# episode  16 score -96.0 avg score -93 steps  5 alpha  1.0
# episode  17 score -95.0 avg score -93 steps  6 alpha  1.0
# episode  18 score -95.0 avg score -93 steps  6 alpha  1.0
# episode  19 score -97.0 avg score -94 steps  4 alpha  1.0
# episode  20 score -97.0 avg score -94 steps  4 alpha  1.0
# episode  21 score -97.0 avg score -94 steps  4 alpha  1.0
# episode  22 score -96.0 avg score -94 steps  5 alpha  1.0
# episode  23 score -98.0 avg score -94 steps  3 alpha  1.0
# episode  24 score -97.0 avg score -94 steps  4 alpha  1.0
# episode  25 score -92.0 avg score -94 steps  9 alpha  1.0
# episode  26 score -89.0 avg score -94 steps  12 alpha  1.0
# episode  27 score -94.0 avg score -94 steps  7 alpha  1.0
# episode  28 score -92.0 avg score -94 steps  9 alpha  1.0
# episode  29 score -98.0 avg score -94 steps  3 alpha  1.0
# episode  30 score -97.0 avg score -94 steps  4 alpha  1.0
# episode  31 score -96.0 avg score -94 steps  5 alpha  1.0
# episode  32 score -94.0 avg score -94 steps  7 alpha  1.0
# episode  33 score -94.0 avg score -94 steps  7 alpha  1.0
# episode  34 score -93.0 avg score -94 steps  8 alpha  1.0
# episode  35 score -93.0 avg score -94 steps  8 alpha  1.0
# Buffer Size equals batch Size! - Learning begins :)
# episode  36 score -85.0 avg score -94 steps  16 alpha  0.99915683
# episode  37 score -97.0 avg score -94 steps  4 alpha  0.9965558
# episode  38 score -97.0 avg score -94 steps  4 alpha  0.99535996
# episode  39 score -97.0 avg score -94 steps  4 alpha  0.9941645
# episode  40 score -94.0 avg score -94 steps  7 alpha  0.9925233
# episode  41 score -97.0 avg score -94 steps  4 alpha  0.99088484
# episode  42 score -94.0 avg score -94 steps  7 alpha  0.98924863
# episode  43 score -94.0 avg score -94 steps  7 alpha  0.9871711
# episode  44 score -96.0 avg score -94 steps  5 alpha  0.9853946
# episode  45 score -95.0 avg score -94 steps  6 alpha  0.98377126
# episode  46 score -97.0 avg score -94 steps  4 alpha  0.9822977
# episode  47 score -94.0 avg score -94 steps  7 alpha  0.9806779
# episode  48 score -94.0 avg score -94 steps  7 alpha  0.9786204
# episode  49 score -97.0 avg score -94 steps  4 alpha  0.97700953
# episode  50 score -80.0 avg score -94 steps  21 alpha  0.9733876
# episode  51 score -97.0 avg score -94 steps  4 alpha  0.96983874
# episode  52 score -90.0 avg score -94 steps  11 alpha  0.9677832
# episode  53 score -87.0 avg score -94 steps  14 alpha  0.96448296
# episode  54 score -93.0 avg score -94 steps  8 alpha  0.96168965
# episode  55 score -97.0 avg score -94 steps  4 alpha  0.96020514
# episode  56 score -97.0 avg score -94 steps  4 alpha  0.95923364
# episode  57 score -94.0 avg score -94 steps  7 alpha  0.95789343
# episode  58 score -96.0 avg score -94 steps  5 alpha  0.9564514
# episode  59 score -95.0 avg score -94 steps  6 alpha  0.9551584
# episode  60 score -96.0 avg score -94 steps  5 alpha  0.9538945
# episode  61 score -96.0 avg score -94 steps  5 alpha  0.95275
# episode  62 score -98.0 avg score -94 steps  3 alpha  0.9518549
# episode  63 score -93.0 avg score -94 steps  8 alpha  0.95065427
# episode  64 score -96.0 avg score -94 steps  5 alpha  0.9492636
# episode  65 score -96.0 avg score -94 steps  5 alpha  0.948213
# episode  66 score -88.0 avg score -94 steps  13 alpha  0.9463529
# episode  67 score -93.0 avg score -94 steps  8 alpha  0.9442159
# episode  68 score -97.0 avg score -94 steps  4 alpha  0.9430537
# episode  69 score -95.0 avg score -94 steps  6 alpha  0.9420862
# episode  70 score -91.0 avg score -94 steps  10 alpha  0.9405835
# episode  71 score -96.0 avg score -94 steps  5 alpha  0.9392541
# episode  72 score -85.0 avg score -94 steps  16 alpha  0.9373617
# episode  73 score -92.0 avg score -94 steps  9 alpha  0.93514323
# episode  74 score -94.0 avg score -94 steps  7 alpha  0.9337691
# episode  75 score -84.0 avg score -94 steps  17 alpha  0.9317982
# episode  76 score -92.0 avg score -94 steps  9 alpha  0.92980194
# episode  77 score -96.0 avg score -94 steps  5 alpha  0.92880094
# episode  78 score -92.0 avg score -94 steps  9 alpha  0.9278382
# episode  79 score -96.0 avg score -94 steps  5 alpha  0.92689973
# episode  80 score -97.0 avg score -94 steps  4 alpha  0.92629796
# episode  81 score -96.0 avg score -94 steps  5 alpha  0.9257205
# episode  82 score -97.0 avg score -94 steps  4 alpha  0.9251665
# episode  83 score -93.0 avg score -94 steps  8 alpha  0.92446065
# episode  84 score -96.0 avg score -94 steps  5 alpha  0.9237329
# episode  85 score -93.0 avg score -94 steps  8 alpha  0.9230974
# episode  86 score -96.0 avg score -94 steps  5 alpha  0.9224981
# episode  87 score -93.0 avg score -94 steps  8 alpha  0.9219438
# episode  88 score -96.0 avg score -94 steps  5 alpha  0.9214042
# episode  89 score -95.0 avg score -94 steps  6 alpha  0.9209445
# episode  90 score -93.0 avg score -94 steps  8 alpha  0.9203843
# episode  91 score -97.0 avg score -94 steps  4 alpha  0.9199315
# episode  92 score -97.0 avg score -94 steps  4 alpha  0.9196251
# episode  93 score -94.0 avg score -94 steps  7 alpha  0.91926557
# episode  94 score -95.0 avg score -94 steps  6 alpha  0.91896605
# episode  95 score -96.0 avg score -94 steps  5 alpha  0.9187087
# episode  96 score -86.0 avg score -94 steps  15 alpha  0.91833526
# episode  97 score -96.0 avg score -94 steps  5 alpha  0.9180312
# episode  98 score -94.0 avg score -94 steps  7 alpha  0.91790426
# episode  99 score -97.0 avg score -94 steps  4 alpha  0.91781044
# episode  100 score -92.0 avg score -94 steps  9 alpha  0.91768813
# episode  101 score -97.0 avg score -94 steps  4 alpha  0.9175738
# episode  102 score -92.0 avg score -94 steps  9 alpha  0.9175306
# episode  103 score -95.0 avg score -94 steps  6 alpha  0.91747195
# episode  104 score -97.0 avg score -94 steps  4 alpha  0.91750723
# episode  105 score -96.0 avg score -94 steps  5 alpha  0.9175351
# episode  106 score -97.0 avg score -94 steps  4 alpha  0.91759473
# episode  107 score -88.0 avg score -94 steps  13 alpha  0.91776425
# episode  108 score -95.0 avg score -94 steps  6 alpha  0.9179532
# episode  109 score -94.0 avg score -94 steps  7 alpha  0.9181517
# episode  110 score -85.0 avg score -94 steps  16 alpha  0.9186005
# episode  111 score -96.0 avg score -94 steps  5 alpha  0.91907835
# episode  112 score -86.0 avg score -94 steps  15 alpha  0.91953444
# episode  113 score -97.0 avg score -94 steps  4 alpha  0.92000264
# episode  114 score -92.0 avg score -94 steps  9 alpha  0.9203524
# episode  115 score -96.0 avg score -94 steps  5 alpha  0.9207872
# episode  116 score -93.0 avg score -94 steps  8 alpha  0.9212015
# episode  117 score -93.0 avg score -94 steps  8 alpha  0.9217433
# episode  118 score -91.0 avg score -94 steps  10 alpha  0.9224534
# episode  119 score -88.0 avg score -94 steps  13 alpha  0.9232824
# episode  120 score -80.0 avg score -94 steps  21 alpha  0.9244363
# episode  121 score -91.0 avg score -94 steps  10 alpha  0.92548645
# episode  122 score -97.0 avg score -94 steps  4 alpha  0.92596734
# episode  123 score -91.0 avg score -94 steps  10 alpha  0.92652094
# episode  124 score -89.0 avg score -94 steps  12 alpha  0.927346
# episode  125 score -97.0 avg score -94 steps  4 alpha  0.92803526
# episode  126 score -95.0 avg score -94 steps  6 alpha  0.9284518
# episode  127 score -93.0 avg score -94 steps  8 alpha  0.9289826
# episode  128 score -96.0 avg score -94 steps  5 alpha  0.9294403
# episode  129 score -96.0 avg score -94 steps  5 alpha  0.9298045
# episode  130 score -90.0 avg score -94 steps  11 alpha  0.93038374
# episode  131 score -93.0 avg score -94 steps  8 alpha  0.93105286
# episode  132 score -90.0 avg score -94 steps  11 alpha  0.9318901
# episode  133 score -95.0 avg score -94 steps  6 alpha  0.93261814
# episode  134 score -97.0 avg score -94 steps  4 alpha  0.9330024
# No warmup anymore!
# episode  135 score -78.0 avg score -93 steps  23 alpha  0.9340117
# episode  136 score -54.0 avg score -93 steps  47 alpha  0.9368153
# episode  137 score -82.0 avg score -93 steps  19 alpha  0.9391861
# episode  138 score -73.0 avg score -93 steps  28 alpha  0.9404895
# episode  139 score -72.0 avg score -93 steps  29 alpha  0.94156176
# episode  140 score -56.0 avg score -92 steps  45 alpha  0.9425321
# episode  141 score -80.1 avg score -92 steps  21 alpha  0.9433578
# episode  142 score -65.0 avg score -92 steps  36 alpha  0.94327176
# episode  143 score -78.0 avg score -92 steps  23 alpha  0.9428397
# episode  144 score -34.0 avg score -91 steps  67 alpha  0.94114345
# episode  145 score -59.0 avg score -91 steps  42 alpha  0.93697727
# episode  146 score -33.0 avg score -90 steps  68 alpha  0.9310822
# episode  147 score -65.0 avg score -90 steps  36 alpha  0.9244428
# episode  148 score -72.0 avg score -89 steps  29 alpha  0.9197659
# episode  149 score -81.0 avg score -89 steps  20 alpha  0.916018
# episode  150 score -76.0 avg score -89 steps  25 alpha  0.9122712
# episode  151 score -69.0 avg score -89 steps  32 alpha  0.907166
# episode  152 score -66.0 avg score -89 steps  35 alpha  0.90065026
# episode  153 score -81.0 avg score -89 steps  20 alpha  0.89524096
# episode  154 score -79.0 avg score -88 steps  22 alpha  0.89090437
# episode  155 score -39.2 avg score -88 steps  62 alpha  0.88227606
# episode  156 score -69.1 avg score -88 steps  32 alpha  0.8725834
# episode  157 score -69.0 avg score -87 steps  32 alpha  0.8655446
# episode  158 score -65.0 avg score -87 steps  36 alpha  0.8582224
# episode  159 score -84.0 avg score -87 steps  17 alpha  0.85207045
# episode  160 score -80.0 avg score -87 steps  21 alpha  0.8478031
# episode  161 score -68.1 avg score -86 steps  33 alpha  0.84151536
# episode  162 score -82.1 avg score -86 steps  19 alpha  0.8354395
# episode  163 score -81.1 avg score -86 steps  20 alpha  0.83074635
# episode  164 score -67.1 avg score -86 steps  34 alpha  0.8245644
# episode  165 score -72.0 avg score -86 steps  29 alpha  0.8171328
# episode  166 score -65.1 avg score -85 steps  36 alpha  0.8098628
# episode  167 score -73.0 avg score -85 steps  28 alpha  0.8025789
# episode  168 score -52.1 avg score -85 steps  49 alpha  0.79408795
# episode  169 score -52.0 avg score -84 steps  49 alpha  0.78339887
# episode  170 score -74.0 avg score -84 steps  27 alpha  0.7749073
# episode  171 score -78.0 avg score -84 steps  23 alpha  0.76954186
# episode  172 score -73.1 avg score -84 steps  28 alpha  0.7642737
# episode  173 score -48.0 avg score -83 steps  53 alpha  0.7561715
# episode  174 score -71.0 avg score -83 steps  30 alpha  0.7474991
# episode  175 score -71.0 avg score -83 steps  30 alpha  0.7410436
# episode  176 score -77.1 avg score -83 steps  24 alpha  0.73538476
# episode  177 score -47.5 avg score -82 steps  54 alpha  0.72717047
# episode  178 score -81.1 avg score -82 steps  20 alpha  0.7193339
# episode  179 score -75.0 avg score -82 steps  26 alpha  0.7144479
# episode  180 score -74.0 avg score -82 steps  27 alpha  0.70864844
# episode  181 score -65.0 avg score -82 steps  36 alpha  0.7017647
# episode  182 score -74.0 avg score -81 steps  27 alpha  0.69505167
# episode  183 score -69.0 avg score -81 steps  32 alpha  0.68885195
# ...save actor...
# episode  184 score -72.0 avg score -81 steps  29 alpha  0.6826776
# ...save actor...
# episode  185 score -70.0 avg score -81 steps  31 alpha  0.6766227
# ...save actor...
# episode  186 score -68.0 avg score -80 steps  33 alpha  0.670308
# ...save actor...
# episode  187 score -76.0 avg score -80 steps  25 alpha  0.6645682
# ...save actor...
# episode  188 score -62.0 avg score -80 steps  39 alpha  0.658035
# ...save actor...
# episode  189 score -67.0 avg score -80 steps  34 alpha  0.6509919
# ...save actor...
# episode  190 score -77.0 avg score -79 steps  24 alpha  0.6453742
# ...save actor...
# episode  191 score -75.0 avg score -79 steps  26 alpha  0.6407273
# ...save actor...
# episode  192 score -76.0 avg score -79 steps  25 alpha  0.63598615
# ...save actor...
# episode  193 score -84.0 avg score -79 steps  17 alpha  0.63196105
# ...save actor...
# episode  194 score -71.0 avg score -79 steps  30 alpha  0.6276556
# ...save actor...
# episode  195 score -83.0 avg score -79 steps  18 alpha  0.623087
# ...save actor...
# episode  196 score -78.0 avg score -78 steps  23 alpha  0.61916614
# ...save actor...
# episode  197 score -71.0 avg score -78 steps  30 alpha  0.6140522
# ...save actor...
# episode  198 score -74.0 avg score -78 steps  27 alpha  0.6085814
# ...save actor...
# episode  199 score -77.0 avg score -78 steps  24 alpha  0.60380685
# ...save actor...
# episode  200 score -70.1 avg score -78 steps  31 alpha  0.59894747
# ...save actor...
# episode  201 score -82.0 avg score -77 steps  19 alpha  0.5946953
# ...save actor...
# episode  202 score -80.0 avg score -77 steps  21 alpha  0.591241
# ...save actor...
# episode  203 score -69.0 avg score -77 steps  32 alpha  0.58678865
# ...save actor...
# episode  204 score -73.0 avg score -77 steps  28 alpha  0.5818859
# ...save actor...
# episode  205 score -81.0 avg score -77 steps  20 alpha  0.57798326
# ...save actor...
# episode  206 score -69.0 avg score -76 steps  32 alpha  0.5739267
# ...save actor...
# episode  207 score -64.0 avg score -76 steps  37 alpha  0.5690951
# ...save actor...
# episode  208 score -70.0 avg score -76 steps  31 alpha  0.5644029
# ...save actor...
# episode  209 score -69.0 avg score -76 steps  32 alpha  0.5599057
# ...save actor...
# episode  210 score -80.0 avg score -76 steps  21 alpha  0.5562339
# ...save actor...
# episode  211 score -82.0 avg score -75 steps  19 alpha  0.5533614
# ...save actor...
# episode  212 score -59.0 avg score -75 steps  42 alpha  0.5491344
# ...save actor...
# episode  213 score -84.0 avg score -75 steps  17 alpha  0.544627
# ...save actor...
# episode  214 score -77.0 avg score -75 steps  24 alpha  0.5416633
# ...save actor...
# episode  215 score -72.0 avg score -75 steps  29 alpha  0.5377694
# ...save actor...
# episode  216 score -76.1 avg score -75 steps  25 alpha  0.5341182
# ...save actor...
# episode  217 score -81.0 avg score -74 steps  20 alpha  0.53102946
# ...save actor...
# episode  218 score -68.0 avg score -74 steps  33 alpha  0.52738917
# ...save actor...
# episode  219 score -78.0 avg score -74 steps  23 alpha  0.5235047
# ...save actor...
# episode  220 score -77.0 avg score -74 steps  24 alpha  0.5199886
# ...save actor...
# episode  221 score -77.0 avg score -74 steps  24 alpha  0.5167044
# ...save actor...
# episode  222 score -61.0 avg score -74 steps  40 alpha  0.5123021
# ...save actor...
# episode  223 score -52.0 avg score -73 steps  49 alpha  0.50564575
# ...save actor...
# episode  224 score -46.0 avg score -73 steps  55 alpha  0.4978216
# ...save actor...
# episode  225 score -76.0 avg score -72 steps  25 alpha  0.4925628
# ...save actor...
# episode  226 score -71.0 avg score -72 steps  30 alpha  0.48888758
# ...save actor...
# episode  227 score -62.0 avg score -72 steps  39 alpha  0.4841067
# ...save actor...
# episode  228 score -70.0 avg score -72 steps  31 alpha  0.47931477
# ...save actor...
# episode  229 score -19.2 avg score -71 steps  83 alpha  0.4727734
# ...save actor...
# episode  230 score -65.0 avg score -71 steps  36 alpha  0.466608
# ...save actor...
# episode  231 score -42.0 avg score -70 steps  59 alpha  0.4615402
# ...save actor...
# episode  232 score -70.0 avg score -70 steps  31 alpha  0.45695814
# ...save actor...
# episode  233 score 0.9 avg score -69 steps  103 alpha  0.4514841
# ...save actor...
# episode  234 score -74.0 avg score -69 steps  27 alpha  0.44636
# ...save actor...
# episode  235 score 3.3 avg score -68 steps  110 alpha  0.4427829
# episode  236 score -59.0 avg score -68 steps  42 alpha  0.43894482
# ...save actor...
# episode  237 score -42.0 avg score -68 steps  59 alpha  0.4365865
# ...save actor...
# episode  238 score -70.1 avg score -68 steps  31 alpha  0.4347488
# ...save actor...
# episode  239 score -51.2 avg score -67 steps  50 alpha  0.43332326
# ...save actor...
# episode  240 score -45.1 avg score -67 steps  56 alpha  0.43179446
# ...save actor...
# episode  241 score -17.2 avg score -67 steps  84 alpha  0.42900473
# ...save actor...
# episode  242 score -41.1 avg score -66 steps  60 alpha  0.42619833
# ...save actor...
# episode  243 score -69.0 avg score -66 steps  32 alpha  0.42410463
# episode  244 score -68.0 avg score -67 steps  33 alpha  0.42263862
# episode  245 score -66.0 avg score -67 steps  35 alpha  0.4210526
# episode  246 score -61.0 avg score -67 steps  40 alpha  0.4194066
# episode  247 score -11.4 avg score -66 steps  90 alpha  0.41594005
# ...save actor...
# episode  248 score -32.3 avg score -66 steps  69 alpha  0.41160646
# ...save actor...
# episode  249 score -8.1 avg score -65 steps  94 alpha  0.4075888
# ...save actor...
# episode  250 score -66.0 avg score -65 steps  35 alpha  0.40468243
# ...save actor...
# episode  251 score -10.0 avg score -65 steps  91 alpha  0.4020459
# ...save actor...
# episode  252 score -65.0 avg score -65 steps  36 alpha  0.39906728
# ...save actor...
# episode  253 score -5.1 avg score -64 steps  96 alpha  0.39612207
# ...save actor...
# episode  254 score -36.4 avg score -63 steps  65 alpha  0.3929806
# episode  255 score -49.0 avg score -64 steps  52 alpha  0.39046675
# episode  256 score -71.0 avg score -64 steps  30 alpha  0.38828173
# ...save actor...
# episode  257 score -5.1 avg score -63 steps  96 alpha  0.38558206
# episode  258 score -69.0 avg score -63 steps  32 alpha  0.38285935
# ...save actor...
# episode  259 score -71.0 avg score -63 steps  30 alpha  0.38124928
# ...save actor...
# episode  260 score -63.0 avg score -63 steps  38 alpha  0.37944403
# episode  261 score -70.0 avg score -63 steps  31 alpha  0.37752002
# ...save actor...
# episode  262 score -47.1 avg score -62 steps  54 alpha  0.37504464
# ...save actor...
# episode  263 score -30.3 avg score -62 steps  71 alpha  0.37100342
# ...save actor...
# episode  264 score -50.3 avg score -62 steps  51 alpha  0.36779827
# ...save actor...
# episode  265 score -22.8 avg score -61 steps  79 alpha  0.36465138
# ...save actor...
# episode  266 score -64.0 avg score -61 steps  37 alpha  0.3613763
# ...save actor...
# episode  267 score -64.0 avg score -61 steps  37 alpha  0.35866696
# episode  268 score -55.1 avg score -61 steps  46 alpha  0.35651517
# episode  269 score -57.0 avg score -61 steps  44 alpha  0.35404152
# ...save actor...
# episode  270 score -57.1 avg score -61 steps  44 alpha  0.35081318
# ...save actor...
# episode  271 score -24.1 avg score -60 steps  78 alpha  0.34644324
# ...save actor...
# episode  272 score -1.0 avg score -60 steps  101 alpha  0.34058264
# ...save actor...
# episode  273 score 23.7 avg score -59 steps  125 alpha  0.33415002
# ...save actor...
# episode  274 score -43.3 avg score -59 steps  58 alpha  0.32911214
# ...save actor...
# episode  275 score 3.3 avg score -58 steps  113 alpha  0.32471538
# ...save actor...
# episode  276 score -25.1 avg score -57 steps  76 alpha  0.31937227
# ...save actor...
# episode  277 score 53.6 avg score -56 steps  155 alpha  0.31170797
# ...save actor...
# episode  278 score -66.0 avg score -56 steps  35 alpha  0.3062233
# ...save actor...
# episode  279 score -23.5 avg score -56 steps  78 alpha  0.30227444
# ...save actor...
# episode  280 score 17.3 avg score -55 steps  119 alpha  0.295041
# ...save actor...
# episode  281 score -23.3 avg score -54 steps  78 alpha  0.28831995
# ...save actor...
# episode  282 score -43.1 avg score -54 steps  58 alpha  0.28364533
# ...save actor...
# episode  283 score -53.1 avg score -54 steps  48 alpha  0.28040633
# ...save actor...
# episode  284 score -62.0 avg score -54 steps  39 alpha  0.27811557
# ...save actor...
# episode  285 score -15.6 avg score -53 steps  87 alpha  0.27403915
# ...save actor...
# episode  286 score 19.6 avg score -52 steps  121 alpha  0.2676774
# ...save actor...
# episode  287 score 0.9 avg score -52 steps  102 alpha  0.26199684
# ...save actor...
# episode  288 score -19.8 avg score -51 steps  84 alpha  0.2579983
# ...save actor...
# episode  289 score 7.0 avg score -51 steps  109 alpha  0.25458866
# ...save actor...
# episode  290 score -23.4 avg score -50 steps  78 alpha  0.24989812
# ...save actor...
# episode  291 score -3.2 avg score -49 steps  103 alpha  0.24537587
# ...save actor...
# episode  292 score 24.2 avg score -48 steps  130 alpha  0.2410812
# ...save actor...
# episode  293 score -10.9 avg score -48 steps  92 alpha  0.23810926
# ...save actor...
# episode  294 score -1.3 avg score -47 steps  101 alpha  0.23623674
# ...save actor...
# episode  295 score 115.3 avg score -45 steps  227 alpha  0.23421966
# ...save actor...
# episode  296 score -3.4 avg score -44 steps  102 alpha  0.23191915
# ...save actor...
# episode  297 score -2.7 avg score -43 steps  102 alpha  0.23028558
# ...save actor...
# episode  298 score 12.1 avg score -43 steps  122 alpha  0.22983234
# ...save actor...
# episode  299 score -10.7 avg score -42 steps  93 alpha  0.22794147
# ...save actor...
# episode  300 score 86.5 avg score -40 steps  196 alpha  0.2252489
# ...save actor...
# episode  301 score 5.1 avg score -39 steps  109 alpha  0.22337069
# ...save actor...
# episode  302 score 120.2 avg score -37 steps  222 alpha  0.2209983
# ...save actor...
# episode  303 score 5.2 avg score -37 steps  112 alpha  0.21818376
# ...save actor...
# episode  304 score 21.8 avg score -36 steps  124 alpha  0.21546121
# ...save actor...
# episode  305 score -12.0 avg score -35 steps  92 alpha  0.21262981
# ...save actor...
# episode  306 score -11.2 avg score -35 steps  93 alpha  0.21063863
# ...save actor...
# episode  307 score 20.9 avg score -34 steps  123 alpha  0.20963655
# ...save actor...
# episode  308 score 12.3 avg score -33 steps  116 alpha  0.20791468
# ...save actor...
# episode  309 score 11.2 avg score -32 steps  115 alpha  0.20559278
# ...save actor...
# episode  310 score -19.1 avg score -31 steps  84 alpha  0.2036616
# ...save actor...
# episode  311 score 229.5 avg score -28 steps  337 alpha  0.20018794
# ...save actor...
# episode  312 score 276.9 avg score -25 steps  385 alpha  0.19469903
# ...save actor...
# episode  313 score 75.1 avg score -23 steps  184 alpha  0.18871288
# ...save actor...
# episode  314 score 18.5 avg score -22 steps  133 alpha  0.18603
# ...save actor...
# episode  315 score 43.3 avg score -21 steps  157 alpha  0.18323547
# ...save actor...
# episode  316 score 81.6 avg score -20 steps  199 alpha  0.1804562
# ...save actor...
# episode  317 score 170.8 avg score -17 steps  273 alpha  0.17731741
# ...save actor...
# episode  318 score 30.9 avg score -16 steps  143 alpha  0.1758306
# ...save actor...
# episode  319 score -1.3 avg score -15 steps  104 alpha  0.17460427
# ...save actor...
# episode  320 score -0.1 avg score -15 steps  103 alpha  0.17379045
# ...save actor...
# episode  321 score -3.6 avg score -14 steps  101 alpha  0.17300569
# ...save actor...
# episode  322 score -13.0 avg score -13 steps  91 alpha  0.17193484
# ...save actor...
# episode  323 score 11.0 avg score -13 steps  117 alpha  0.17113923
# ...save actor...
# episode  324 score 22.2 avg score -12 steps  129 alpha  0.17001931
# ...save actor...
# episode  325 score 33.6 avg score -11 steps  138 alpha  0.16943346
# ...save actor...
# episode  326 score 5.8 avg score -10 steps  110 alpha  0.16877526
# ...save actor...
# episode  327 score 4.0 avg score -10 steps  108 alpha  0.1681792
# ...save actor...
# episode  328 score 48.6 avg score -8 steps  158 alpha  0.16641296
# episode  329 score -27.0 avg score -8 steps  76 alpha  0.16633618
# ...save actor...
# episode  330 score 46.4 avg score -7 steps  151 alpha  0.16524456
# ...save actor...
# episode  331 score -9.6 avg score -7 steps  94 alpha  0.16415326
# ...save actor...
# episode  332 score 117.2 avg score -5 steps  224 alpha  0.16165386
# ...save actor...
# episode  333 score 6.6 avg score -5 steps  110 alpha  0.1592907
# ...save actor...
# episode  334 score -0.6 avg score -4 steps  103 alpha  0.15848763
# ...save actor...
# episode  335 score 12.5 avg score -4 steps  116 alpha  0.15796123
# ...save actor...
# episode  336 score 17.9 avg score -4 steps  121 alpha  0.15738519
# ...save actor...
# episode  337 score 85.9 avg score -2 steps  189 alpha  0.15468778
# ...save actor...
# episode  338 score 2.7 avg score -2 steps  108 alpha  0.1527234
# ...save actor...
# episode  339 score 23.2 avg score -1 steps  127 alpha  0.15100309
# ...save actor...
# episode  340 score -7.3 avg score -0 steps  96 alpha  0.14973001
# ...save actor...
# episode  341 score -6.3 avg score -0 steps  98 alpha  0.14768803
# ...save actor...
# episode  342 score 8.2 avg score 0 steps  112 alpha  0.14730369
# ...save actor...
# episode  343 score 44.1 avg score 1 steps  166 alpha  0.14528948
# ...save actor...
# episode  344 score 186.2 avg score 4 steps  291 alpha  0.14207587
# ...save actor...
# episode  345 score 92.2 avg score 5 steps  196 alpha  0.14026135
# ...save actor...
# episode  346 score 20.9 avg score 6 steps  130 alpha  0.13854805
# ...save actor...
# episode  347 score 99.0 avg score 7 steps  209 alpha  0.13701089
# ...save actor...
# episode  348 score -13.7 avg score 8 steps  90 alpha  0.13572815
# ...save actor...
# episode  349 score 39.6 avg score 8 steps  143 alpha  0.13468198
# ...save actor...
# episode  350 score 96.4 avg score 10 steps  205 alpha  0.13213189
# ...save actor...
# episode  351 score 50.6 avg score 10 steps  156 alpha  0.13067459
# ...save actor...
# episode  352 score 42.3 avg score 11 steps  150 alpha  0.13002233
# ...save actor...
# episode  353 score 36.6 avg score 12 steps  153 alpha  0.12848744
# ...save actor...
# episode  354 score 10.6 avg score 12 steps  131 alpha  0.12726691
# ...save actor...
# episode  355 score 71.7 avg score 13 steps  179 alpha  0.12714379
# ...save actor...
# episode  356 score 283.7 avg score 17 steps  405 alpha  0.12685914
# ...save actor...
# episode  357 score 54.2 avg score 18 steps  166 alpha  0.12574452
# ...save actor...
# episode  358 score 203.5 avg score 20 steps  334 alpha  0.124833606
# ...save actor...
# episode  359 score 167.0 avg score 23 steps  292 alpha  0.12420096
# ...save actor...
# episode  360 score 42.0 avg score 24 steps  156 alpha  0.12300051
# ...save actor...
# episode  361 score 46.0 avg score 25 steps  153 alpha  0.12242775
# ...save actor...
# episode  362 score 16.9 avg score 26 steps  124 alpha  0.12395288
# ...save actor...
# episode  363 score 294.9 avg score 29 steps  413 alpha  0.12602042
# ...save actor...
# episode  364 score 174.3 avg score 31 steps  291 alpha  0.12641588
# ...save actor...
# episode  365 score 46.8 avg score 32 steps  158 alpha  0.12604511
# ...save actor...
# episode  366 score 183.7 avg score 34 steps  302 alpha  0.1253945
# ...save actor...
# episode  367 score 211.3 avg score 37 steps  334 alpha  0.12557414
# ...save actor...
# episode  368 score 315.7 avg score 41 steps  429 alpha  0.12619498
# ...save actor...
# episode  369 score 265.4 avg score 44 steps  395 alpha  0.12635437
# ...save actor...
# episode  370 score 598.9 avg score 50 steps  500 alpha  0.12799348
# ...save actor...
# episode  371 score 137.6 avg score 52 steps  254 alpha  0.12899545
# ...save actor...
# episode  372 score 252.3 avg score 55 steps  381 alpha  0.1301385
# ...save actor...
# episode  373 score 598.9 avg score 60 steps  500 alpha  0.12982269
# ...save actor...
# episode  374 score 598.9 avg score 67 steps  500 alpha  0.1304515
# ...save actor...
# episode  375 score 598.9 avg score 73 steps  500 alpha  0.1319548
# ...save actor...
# episode  376 score 598.9 avg score 79 steps  500 alpha  0.13401765
# ...save actor...
# episode  377 score 598.7 avg score 84 steps  500 alpha  0.13346289
# ...save actor...
# episode  378 score 598.9 avg score 91 steps  500 alpha  0.13347562
# ...save actor...
# episode  379 score 598.7 avg score 97 steps  500 alpha  0.13212597
# ...save actor...
# episode  380 score 598.9 avg score 103 steps  500 alpha  0.1295709
# ...save actor...
# episode  381 score 598.9 avg score 109 steps  500 alpha  0.12894803
# ...save actor...
# episode  382 score 100.2 avg score 111 steps  222 alpha  0.12912795
# ...save actor...
# episode  383 score 598.8 avg score 117 steps  500 alpha  0.12900686
# ...save actor...
# episode  384 score 598.9 avg score 124 steps  500 alpha  0.12534817
# ...save actor...
# episode  385 score 596.9 avg score 130 steps  500 alpha  0.12338382
# ...save actor...
# episode  386 score 598.9 avg score 136 steps  500 alpha  0.1240531
# ...save actor...
# episode  387 score 598.8 avg score 142 steps  500 alpha  0.1259562
# ...save actor...
# episode  388 score 598.8 avg score 148 steps  500 alpha  0.1275864
# ...save actor...
# episode  389 score 598.9 avg score 154 steps  500 alpha  0.12711735
# ...save actor...
# episode  390 score 598.2 avg score 160 steps  500 alpha  0.12794355
# ...save actor...
# episode  391 score 230.2 avg score 162 steps  350 alpha  0.13022389
# ...save actor...
# episode  392 score 598.8 avg score 168 steps  500 alpha  0.1310251
# ...save actor...
# episode  393 score 132.4 avg score 170 steps  249 alpha  0.12980437
# ...save actor...
# episode  394 score 598.9 avg score 176 steps  500 alpha  0.12764716
# ...save actor...
# episode  395 score 598.5 avg score 180 steps  500 alpha  0.12316943
# ...save actor...
# episode  396 score 598.8 avg score 186 steps  500 alpha  0.11985494
# ...save actor...
# episode  397 score 598.9 avg score 193 steps  500 alpha  0.115839876
# ...save actor...
# episode  398 score 598.7 avg score 198 steps  500 alpha  0.11204792
# ...save actor...
# episode  399 score 598.8 avg score 204 steps  500 alpha  0.10949994
# ...save actor...
# episode  400 score 598.8 avg score 210 steps  500 alpha  0.10508217
# ...save actor...
# episode  401 score 599.0 avg score 216 steps  500 alpha  0.10336299
# ...save actor...
# episode  402 score 598.7 avg score 220 steps  500 alpha  0.10224737
# ...save actor...
# episode  403 score 598.4 avg score 226 steps  500 alpha  0.099488236
# ...save actor...
# episode  404 score 599.0 avg score 232 steps  500 alpha  0.09653072
# ...save actor...
# episode  405 score 598.9 avg score 238 steps  500 alpha  0.096133955
# ...save actor...
# episode  406 score 597.2 avg score 244 steps  500 alpha  0.096295916
# ...save actor...
# episode  407 score 599.0 avg score 250 steps  500 alpha  0.09493295
# ...save actor...
# episode  408 score 598.9 avg score 256 steps  500 alpha  0.0948087
# ...save actor...
# episode  409 score 597.3 avg score 262 steps  500 alpha  0.09398923
# ...save actor...
# episode  410 score 598.9 avg score 268 steps  500 alpha  0.09144241
# ...save actor...
# episode  411 score 598.7 avg score 272 steps  500 alpha  0.08944286
# ...save actor...
# episode  412 score 599.0 avg score 275 steps  500 alpha  0.0889848
# ...save actor...
# episode  413 score 598.1 avg score 280 steps  500 alpha  0.08762231
# ...save actor...
# episode  414 score 599.0 avg score 286 steps  500 alpha  0.08408584
# ...save actor...
# episode  415 score 598.9 avg score 291 steps  500 alpha  0.081917316
# ...save actor...
# episode  416 score 598.7 avg score 297 steps  500 alpha  0.08092267
# ...save actor...
# episode  417 score 599.0 avg score 301 steps  500 alpha  0.079075254
# ...save actor...
# episode  418 score 599.0 avg score 307 steps  500 alpha  0.07916733
# ...save actor...
# episode  419 score 598.9 avg score 313 steps  500 alpha  0.07963436
# ...save actor...
# episode  420 score 598.9 avg score 319 steps  500 alpha  0.07695698
# ...save actor...
# episode  421 score 597.6 avg score 325 steps  500 alpha  0.07516954
# ...save actor...
# episode  422 score 598.3 avg score 331 steps  500 alpha  0.07381665
# ...save actor...
# episode  423 score 598.9 avg score 337 steps  500 alpha  0.07861421
# ...save actor...
# episode  424 score 598.8 avg score 342 steps  500 alpha  0.07817676
# ...save actor...
# episode  425 score 598.9 avg score 348 steps  500 alpha  0.07673901
# ...save actor...
# episode  426 score 598.9 avg score 354 steps  500 alpha  0.07585632
# ...save actor...
# episode  427 score 598.9 avg score 360 steps  500 alpha  0.072957
# ...save actor...
# episode  428 score 598.9 avg score 365 steps  500 alpha  0.07106322
# ...save actor...
# episode  429 score 598.8 avg score 372 steps  500 alpha  0.07036371
# ...save actor...
# episode  430 score 598.9 avg score 377 steps  500 alpha  0.068127595
# ...save actor...
# episode  431 score 599.0 avg score 383 steps  500 alpha  0.06690322
# ...save actor...
# episode  432 score 598.9 avg score 388 steps  500 alpha  0.06795908
# ...save actor...
# episode  433 score 598.8 avg score 394 steps  500 alpha  0.06663511
# ...save actor...
# episode  434 score 599.0 avg score 400 steps  500 alpha  0.06421811
# ...save actor...
# episode  435 score 598.9 avg score 406 steps  500 alpha  0.062431946
# ...save actor...
# episode  436 score 598.9 avg score 412 steps  500 alpha  0.060998023
# ...save actor...
# episode  437 score 598.9 avg score 417 steps  500 alpha  0.059680816
# ...save actor...
# episode  438 score 598.9 avg score 423 steps  500 alpha  0.059073802
# ...save actor...
# episode  439 score 599.0 avg score 428 steps  500 alpha  0.058214728
# ...save actor...
# episode  440 score 599.0 avg score 435 steps  500 alpha  0.05768995
# ...save actor...
# episode  441 score 598.8 avg score 441 steps  500 alpha  0.057254966
# ...save actor...
# episode  442 score 598.8 avg score 446 steps  500 alpha  0.056755356
# ...save actor...
# episode  443 score 599.0 avg score 452 steps  500 alpha  0.0566308
# ...save actor...
# episode  444 score 598.7 avg score 456 steps  500 alpha  0.056236517
# ...save actor...
# episode  445 score 598.6 avg score 461 steps  500 alpha  0.055892594
# ...save actor...
# episode  446 score 599.0 avg score 467 steps  500 alpha  0.055593885
# ...save actor...
# episode  447 score 599.0 avg score 472 steps  500 alpha  0.056365333
# ...save actor...
# episode  448 score 598.8 avg score 478 steps  500 alpha  0.054671433
# ...save actor...
# episode  449 score 597.8 avg score 484 steps  500 alpha  0.052064095
# ...save actor...
# episode  450 score 598.5 avg score 489 steps  500 alpha  0.049746294
# ...save actor...
# episode  451 score 598.4 avg score 494 steps  500 alpha  0.047966607
# ...save actor...
# episode  452 score 598.8 avg score 500 steps  500 alpha  0.04678074
# ...save actor...
# episode  453 score 598.8 avg score 505 steps  500 alpha  0.04628784
# ...save actor...
# episode  454 score 598.8 avg score 511 steps  500 alpha  0.04785628
# ...save actor...
# episode  455 score 598.8 avg score 517 steps  500 alpha  0.04907148
# ...save actor...
# episode  456 score 598.7 avg score 520 steps  500 alpha  0.049499664
# ...save actor...
# episode  457 score 598.1 avg score 525 steps  500 alpha  0.049253464
# ...save actor...
# episode  458 score 598.7 avg score 529 steps  500 alpha  0.04774063
# ...save actor...
# episode  459 score 598.2 avg score 533 steps  500 alpha  0.045256335
# ...save actor...
# episode  460 score 598.3 avg score 539 steps  500 alpha  0.04538961
# ...save actor...
# episode  461 score 598.4 avg score 544 steps  500 alpha  0.044505816
# ...save actor...
# episode  462 score 598.8 avg score 550 steps  500 alpha  0.04531779
# episode  463 score 281.9 avg score 550 steps  425 alpha  0.045652565
# ...save actor...
# episode  464 score 594.8 avg score 554 steps  500 alpha  0.045415964
# ...save actor...
# episode  465 score 350.1 avg score 557 steps  493 alpha  0.045868274
# ...save actor...
# episode  466 score 186.7 avg score 557 steps  330 alpha  0.04574003
# ...save actor...
# episode  467 score 598.8 avg score 561 steps  500 alpha  0.044646554
# ...save actor...
# episode  468 score 598.5 avg score 564 steps  500 alpha  0.04427037
# ...save actor...
# episode  469 score 598.9 avg score 567 steps  500 alpha  0.0447814
# episode  470 score 598.4 avg score 567 steps  500 alpha  0.04500367
# ...save actor...
# episode  471 score 598.9 avg score 572 steps  500 alpha  0.045576595
# ...save actor...
# episode  472 score 598.9 avg score 576 steps  500 alpha  0.044895235
# episode  473 score 116.9 avg score 571 steps  252 alpha  0.0439399
# episode  474 score 598.9 avg score 571 steps  500 alpha  0.043968156
# episode  475 score 598.9 avg score 571 steps  500 alpha  0.043826614
# episode  476 score 598.6 avg score 571 steps  500 alpha  0.042466953
# episode  477 score 598.9 avg score 571 steps  500 alpha  0.04256137
# episode  478 score 599.0 avg score 571 steps  500 alpha  0.04110395
# episode  479 score 599.0 avg score 571 steps  500 alpha  0.043321084
# episode  480 score 191.1 avg score 567 steps  333 alpha  0.04539116
# episode  481 score 598.8 avg score 567 steps  500 alpha  0.046684463
# episode  482 score 598.9 avg score 572 steps  500 alpha  0.047245782
# episode  483 score 597.7 avg score 572 steps  500 alpha  0.04750583
# episode  484 score 598.9 avg score 572 steps  500 alpha  0.04681912
# episode  485 score 598.9 avg score 572 steps  500 alpha  0.04665054
# episode  486 score 598.9 avg score 572 steps  500 alpha  0.046761587
# episode  487 score 598.7 avg score 572 steps  500 alpha  0.046114028
# episode  488 score 597.5 avg score 572 steps  500 alpha  0.045003206
# episode  489 score 599.0 avg score 572 steps  500 alpha  0.044221643
# episode  490 score 599.0 avg score 572 steps  500 alpha  0.045243382
# episode  491 score 598.9 avg score 575 steps  500 alpha  0.0461764
# episode  492 score 599.0 avg score 575 steps  500 alpha  0.04661421
# ...save actor...
# episode  493 score 599.0 avg score 580 steps  500 alpha  0.047854465
# ...save actor...
# episode  494 score 599.0 avg score 580 steps  500 alpha  0.04786817
# ...save actor...
# episode  495 score 598.8 avg score 580 steps  500 alpha  0.047676384
# ...save actor...
# episode  496 score 598.9 avg score 580 steps  500 alpha  0.04740742
# episode  497 score 598.9 avg score 580 steps  500 alpha  0.047938906
# ...save actor...
# episode  498 score 598.9 avg score 580 steps  500 alpha  0.047162
# ...save actor...
# episode  499 score 598.9 avg score 580 steps  500 alpha  0.04661856
# ...save actor...
# episode  500 score 598.9 avg score 580 steps  500 alpha  0.045390848
# ...save actor...
# episode  501 score 599.0 avg score 580 steps  500 alpha  0.043780997
# episode  502 score 597.6 avg score 580 steps  500 alpha  0.04310263
# episode  503 score 599.0 avg score 580 steps  500 alpha  0.04189927
# episode  504 score 598.7 avg score 580 steps  500 alpha  0.04121673
# episode  505 score 598.9 avg score 580 steps  500 alpha  0.039638024
# ...save actor...
# episode  506 score 599.0 avg score 580 steps  500 alpha  0.03812832
# episode  507 score 597.5 avg score 580 steps  500 alpha  0.03722217
# episode  508 score 597.8 avg score 580 steps  500 alpha  0.03674542
# episode  509 score 597.7 avg score 580 steps  500 alpha  0.037675224
# episode  510 score 598.9 avg score 580 steps  500 alpha  0.037535004
# episode  511 score 598.8 avg score 580 steps  500 alpha  0.035785258
# episode  512 score 597.6 avg score 580 steps  500 alpha  0.03570793
# episode  513 score 597.5 avg score 580 steps  500 alpha  0.035446975
# episode  514 score 598.0 avg score 580 steps  500 alpha  0.035249665
# episode  515 score 598.2 avg score 580 steps  500 alpha  0.034444503
# episode  516 score 599.0 avg score 580 steps  500 alpha  0.034689136
# episode  517 score 598.6 avg score 580 steps  500 alpha  0.033914305
# episode  518 score 599.0 avg score 580 steps  500 alpha  0.033591744
# episode  519 score 597.2 avg score 580 steps  500 alpha  0.033171553
# episode  520 score 598.5 avg score 580 steps  500 alpha  0.03275918
# episode  521 score 598.9 avg score 580 steps  500 alpha  0.03202863
# episode  522 score 598.9 avg score 580 steps  500 alpha  0.031433363
# episode  523 score 598.4 avg score 580 steps  500 alpha  0.031445768
# episode  524 score 598.5 avg score 580 steps  500 alpha  0.030988472
# episode  525 score 597.8 avg score 580 steps  500 alpha  0.031193675
# episode  526 score 597.8 avg score 580 steps  500 alpha  0.031946056
# episode  527 score 598.6 avg score 580 steps  500 alpha  0.03241627
# episode  528 score 598.0 avg score 580 steps  500 alpha  0.033574626
# episode  529 score 598.8 avg score 580 steps  500 alpha  0.03421304
# episode  530 score 598.9 avg score 580 steps  500 alpha  0.034369104
# episode  531 score 598.9 avg score 580 steps  500 alpha  0.03419244
# episode  532 score 599.0 avg score 580 steps  500 alpha  0.033369362
# episode  533 score 598.9 avg score 580 steps  500 alpha  0.03236737
# episode  534 score 598.7 avg score 580 steps  500 alpha  0.032143924
# episode  535 score 598.9 avg score 580 steps  500 alpha  0.03188737
# episode  536 score 599.0 avg score 580 steps  500 alpha  0.032194175
# episode  537 score 598.4 avg score 580 steps  500 alpha  0.032424007
# episode  538 score 599.0 avg score 580 steps  500 alpha  0.032602828
# episode  539 score 598.9 avg score 580 steps  500 alpha  0.033875745
# episode  540 score 599.0 avg score 580 steps  500 alpha  0.032936193
# episode  541 score 599.0 avg score 580 steps  500 alpha  0.032742534
# episode  542 score 597.8 avg score 580 steps  500 alpha  0.0320158
# episode  543 score 598.8 avg score 580 steps  500 alpha  0.031572077
# episode  544 score 598.9 avg score 580 steps  500 alpha  0.031180127
# episode  545 score 597.6 avg score 580 steps  500 alpha  0.03194153
# episode  546 score 598.3 avg score 580 steps  500 alpha  0.031817988
# episode  547 score 598.9 avg score 580 steps  500 alpha  0.03088418
# episode  548 score 598.9 avg score 580 steps  500 alpha  0.029856117
# episode  549 score 598.9 avg score 580 steps  500 alpha  0.028320186
# episode  550 score 599.0 avg score 580 steps  500 alpha  0.02892706
# episode  551 score 598.9 avg score 580 steps  500 alpha  0.028732847
# episode  552 score 598.8 avg score 580 steps  500 alpha  0.02885821
# episode  553 score 597.5 avg score 580 steps  500 alpha  0.029108237
# episode  554 score 598.4 avg score 580 steps  500 alpha  0.029881503
# episode  555 score 599.0 avg score 580 steps  500 alpha  0.030649466
# episode  556 score 597.6 avg score 580 steps  500 alpha  0.03131425
# episode  557 score 598.9 avg score 580 steps  500 alpha  0.029969137
# episode  558 score 598.1 avg score 580 steps  500 alpha  0.030196927
# episode  559 score 598.8 avg score 580 steps  500 alpha  0.029847957
# episode  560 score 598.9 avg score 580 steps  500 alpha  0.029317128
# episode  561 score 598.5 avg score 580 steps  500 alpha  0.029302428
# episode  562 score 597.9 avg score 580 steps  500 alpha  0.02898307
# ...save actor...
# episode  563 score 598.4 avg score 583 steps  500 alpha  0.028136592
# ...save actor...
# episode  564 score 598.5 avg score 583 steps  500 alpha  0.029108372
# ...save actor...
# episode  565 score 598.1 avg score 586 steps  500 alpha  0.029322574
# ...save actor...
# episode  566 score 598.5 avg score 590 steps  500 alpha  0.029238578
# episode  567 score 598.7 avg score 590 steps  500 alpha  0.02888089
# ...save actor...
# episode  568 score 598.8 avg score 590 steps  500 alpha  0.027585564
# episode  569 score 598.7 avg score 590 steps  500 alpha  0.027089868
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3ef1ced6c970> in <module>
#      25         observation_, reward, done = env.step(action)
#      26         agent.remember(observation, action, reward, observation_, done)
# ---> 27         agent.learn()
#      28         observation = observation_
#      29         score += reward
#
# <ipython-input-6-fe1c92459723> in learn(self)
#     210                 Q2 = self.q_net2(states, new_actions)
#     211                 Q_min = tf.minimum(Q1, Q2)
# --> 212                 loss_policy = tf.reduce_mean(self.alpha * log_pi - Q_min)
#     213
#     214             grad_policy = tape_policy.gradient(loss_policy, self.policy_net.trainable_variables)
#
# ~\anaconda3\envs\TF\lib\site-packages\tensorflow_core\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     900     with ops.name_scope(None, op_name, [x, y]) as name:
#     901       if isinstance(x, ops.Tensor) and isinstance(y, ops.Tensor):
# --> 902         return func(x, y, name=name)
#     903       elif not isinstance(y, sparse_tensor.SparseTensor):
#     904         try:
#
# ~\anaconda3\envs\TF\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in sub(x, y, name)
#   10089       _result = _pywrap_tensorflow.TFE_Py_FastPathExecute(
#   10090         _ctx._context_handle, tld.device_name, "Sub", name, tld.op_callbacks,
# > 10091         x, y)
#   10092       return _result
#   10093     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Learning Curve

# %%
plot_learning_curve(score_history, figure_file_return+'.png', color='lightgreen', avg_color='green', Ylabel='Return')
plot_learning_curve(alpha_history, figure_file_alpha+'.png', color='blue', Ylabel='Temperature alpha')

np.save(figure_file_return, score_history)

# %% [markdown]
# ## Evaluation

# %%
x = []
theta1 = []
theta2 = []
dx = []
dtheta1 = []
dtheta2 = []
force = []

for i in range(1):
    observation = env.reset()
    done = False
    while not done:
        x.append(observation[0])
        theta1.append(observation[1])
        theta2.append(observation[2])
        dx.append(observation[3])
        dtheta1.append(observation[4])
        dtheta2.append(observation[5])
        action = agent.choose_action(observation)
        force.append(action)
        observation_, _, done = env.step(action)
        observation = observation_
    
n_steps = len(x)
t = [env.dt*i for i in range(n_steps)]

plt.plot(t, np.rad2deg(theta1), label='phi1', color='green')
plt.title('pendulum 1 angle')
plt.ylabel('phi1 [deg]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'phi_1.png')
plt.show()

plt.plot(t, np.rad2deg(theta2), label='phi1', color='red')
plt.title('pendulum 2 angle')
plt.ylabel('phi2 [deg]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'phi_2.png')
plt.show()


plt.plot(t, x, label='x')
plt.title('cart position')
plt.ylabel('x [m]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'cart_distance.png')
plt.show()


plt.plot(t, dx, label='dx')
plt.plot(t, dtheta1, label='dphi1')
plt.plot(t, dtheta2, label='dphi2')
plt.title('velocities')
plt.ylabel('dx [m/s]   dphi1, dphi2 [rad/s]')
plt.xlabel('time [s]')
plt.legend()
plt.savefig('plots/' + 'velocities.png')
plt.show()


plt.plot(t, force)
plt.title('horizontal force on cart')
plt.ylabel('F [N]')
plt.xlabel('time [s]')
plt.savefig('plots/' + 'control_variable.png')
plt.show()


l1, l2 = 0.35, 0.48

x_u = [x[i] + l1*sin(theta1[i]) for i in range(len(x))]
y_u = [l1*cos(theta1[i]) for i in range(len(x))]

x_o = [x[i] + l1*sin(theta1[i]) + l2*sin(theta2[i]) for i in range(len(x))]
y_o = [l1*cos(theta1[i]) + l2*cos(theta2[i]) for i in range(len(x))]

plt.plot(x_u, y_u)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()

plt.plot(x_o, y_o)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()

plt.plot(x_u, y_u)
plt.plot(x_o, y_o)
plt.title('Trajektorie')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
plt.show()
